# %% [markdown]
# # Notebook 2: Labelling

# %%
import re
import os
import json

AUTO_DATA_PATH = os.path.join('..', 'data', 'raw', 'auto')

print(f"Data path: {os.path.abspath(AUTO_DATA_PATH)}")

paper_ids = [d for d in os.listdir(AUTO_DATA_PATH) if os.path.isdir(os.path.join(AUTO_DATA_PATH, d))]
paper_ids.sort()
# Out:
# Data path: /Users/thomas200905/Documents/Thomas/HCMUS/Third Year/Semester 7/Intro to Data Science/Milestones/MS02/data/raw/auto

# %% [markdown]
# ## 1. Extract References
# ### 1.1 From .bib and .tex files

# %%
def clean_latex_string(text):
    if not text:
        return ""
    
    # remove \bibinfo{type}{content} -> content
    text = re.sub(r'\\bibinfo\{.*?\}\{(.*?)\}', r'\1', text)

    # remove latex commands
    text = re.sub(r'\\[a-zA-Z]+\{(.*?)\}', r'\1', text)

    # remove newlines
    text = text.replace('\n', ' ').strip()
    text = re.sub(r'\s+', ' ', text)

    return text

def get_field(field_name, entry):
    field_pattern = re.compile(fr'\b{field_name}\s*=\s*\{{((?:[^{{}}]|\{{[^{{}}]*\}})*)\}}', re.IGNORECASE | re.DOTALL)
    match = field_pattern.search(entry)
    
    if match:
        return match.group(1)
    
    pat_quotes = re.compile(fr'\b{field_name}\s*=\s*\"(.*?)\"', re.IGNORECASE | re.DOTALL)
    match = pat_quotes.search(entry)
    
    if match:
        return match.group(1)  
    else: 
        return None

def extract_from_bib(file_content):
    references = []
    raw_entries = re.split(r'^@', file_content, flags=re.MULTILINE)
    
    for entry in raw_entries:
        entry = entry.strip()
        if not entry or entry.startswith('%'): 
            continue
            
        key_match = re.search(r'^(\w+)\s*\{\s*([^,]+),', entry)
        if not key_match:
            continue
            
        ref_type = key_match.group(1)
        ref_id = key_match.group(2).strip()

        if ref_type.lower() in ['string', 'comment', 'preamble']:
            continue
        
        title_raw = get_field('title', entry)
        year_raw = get_field('year', entry)
        author_raw = get_field('author', entry)
        
        if title_raw:
            title = clean_latex_string(title_raw) 
        else:
            title = ""
        
        if year_raw:
            year = year_raw 
        else: 
            year = ""
        
        authors = []
        if author_raw:
            raw_authors = clean_latex_string(author_raw)
            authors = [a.strip() for a in raw_authors.split(' and ')]

        references.append({
            "id": ref_id,
            "title": title,
            "authors": authors,
            "year": year,
            "source_type": "bib"
        })
        
    return references

def extract_from_bibitem(file_content):
    references = []
    
    raw_items = re.split(r'\\bibitem', file_content)
    
    bibinfo_pattern = re.compile(r'\\bibinfo\{(.*?)\}\{((?:[^{}]|\{[^{}]*\})*)\}', re.DOTALL | re.IGNORECASE)
    title_italic_pattern = re.compile(r'(?:\{\\em\s+|\\emph\{|\\textit\{)((?:[^{}]|\{[^{}]*\})*)\}', re.IGNORECASE | re.DOTALL)
    year_pattern = re.compile(r'\((\d{4})\)')

    for item in raw_items:
        if not item.strip(): continue
        
        id_match = re.search(r'^\{([^}]+)\}', item.strip())
        if not id_match: 
            continue

        ref_id = id_match.group(1).strip()
        
        if r'\bibinfo' in item:
            fields = {'author': [], 'title': '', 'year': ''}
            for key, value in bibinfo_pattern.findall(item):
                key = key.lower()
                clean_val = clean_latex_string(value)
                if key == 'author':
                    fields['author'].append(clean_val)
                else:
                    fields[key] = clean_val
            
            title = fields['title']
            authors = fields['author']
            year = fields['year']
            
        else:
            title_match = title_italic_pattern.search(item)
            if title_match:
                title = clean_latex_string(title_match.group(1))

                title_start_index = item.find(title_match.group(0))
                id_end_index = item.find('}') + 1
                
                if title_start_index > id_end_index:
                    raw_authors = item[id_end_index:title_start_index]
                    clean_auth_str = clean_latex_string(raw_authors)
                    authors = [clean_auth_str]
                else:
                    authors = []
            else:
                id_end_index = item.find('}') + 1
                title = clean_latex_string(item[id_end_index:])
                authors = []

            year_match = year_pattern.search(item)
            year = year_match.group(1) if year_match else ""

        references.append({
            "id": ref_id,
            "title": title,
            "authors": authors,
            "year": year,
            "source_type": "bibitem"
        })
            
    return references

# %%
def get_paper_references(paper_id, data_path):
    if not data_path:
        paper_path = os.path.join(AUTO_DATA_PATH, paper_id)
    else:
        paper_path = os.path.join(data_path, paper_id)

    unique_references = {} 
    
    # search for all .bib files
    for root, dirs, files in os.walk(paper_path):
        for file in files:
            if file.endswith(".bib"):
                try:
                    with open(os.path.join(root, file), 'r', encoding='utf-8', errors='ignore') as f:
                        content = f.read()
                        extracted_references = extract_from_bib(content)
                        
                        for reference in extracted_references:
                            if reference['id'] not in unique_references:
                                unique_references[reference['id']] = reference
                except Exception as e:
                    print(f"Error parsing {file}: {e}")

    # search for all .tex files
    for root, dirs, files in os.walk(paper_path):
        for file in files:
            if file.endswith(".tex"):
                try:
                    with open(os.path.join(root, file), 'r', encoding='utf-8', errors='ignore') as f:
                        content = f.read()
                        
                        extracted_references = extract_from_bibitem(content)
                        
                        for reference in extracted_references:
                            if reference['id'] not in unique_references:
                                unique_references[reference['id']] = reference
                except Exception as e:
                    print(f"Error parsing {file}: {e}")
            
    return list(unique_references.values())

# %%
all_papers_refs = {}

for pid in paper_ids:
    print(f"Processing Paper ID: {pid}")
    
    refs = get_paper_references(pid, AUTO_DATA_PATH)
    all_papers_refs[pid] = refs
    
    print(f"  -> Extracted {len(refs)} references.")
    print("-" * 40)

# DEBUG
k = 5
if len(paper_ids) > 0:
    sample_pid = paper_ids[2]
    print(f"\nExample Output for {sample_pid} (First {k} refs):")
    print(json.dumps(all_papers_refs[sample_pid][-k:-1], indent=4))
# Out:
# Processing Paper ID: 2211.03001
#   -> Extracted 79 references.
# ----------------------------------------
# Processing Paper ID: 2211.03002
#   -> Extracted 29 references.
# ----------------------------------------
# Processing Paper ID: 2211.03003
#   -> Extracted 73 references.
# ----------------------------------------
# Processing Paper ID: 2211.03004
#   -> Extracted 287 references.
# ----------------------------------------
# Processing Paper ID: 2211.03005
#   -> Extracted 131 references.
# ----------------------------------------
# Processing Paper ID: 2211.03006
#   -> Extracted 39 references.
# ----------------------------------------
# Processing Paper ID: 2211.03007
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03008
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03009
#   -> Extracted 130 references.
# ----------------------------------------
# Processing Paper ID: 2211.03010
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03011
#   -> Extracted 154 references.
# ----------------------------------------
# Processing Paper ID: 2211.03012
#   -> Extracted 73 references.
# ----------------------------------------
# Processing Paper ID: 2211.03013
#   -> Extracted 74606 references.
# ----------------------------------------
# Processing Paper ID: 2211.03014
#   -> Extracted 36 references.
# ----------------------------------------
# Processing Paper ID: 2211.03015
#   -> Extracted 101 references.
# ----------------------------------------
# Processing Paper ID: 2211.03017
#   -> Extracted 60 references.
# ----------------------------------------
# Processing Paper ID: 2211.03018
#   -> Extracted 30 references.
# ----------------------------------------
# Processing Paper ID: 2211.03019
#   -> Extracted 41 references.
# ----------------------------------------
# Processing Paper ID: 2211.03020
#   -> Extracted 38 references.
# ----------------------------------------
# Processing Paper ID: 2211.03021
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03022
#   -> Extracted 46 references.
# ----------------------------------------
# Processing Paper ID: 2211.03023
#   -> Extracted 32 references.
# ----------------------------------------
# Processing Paper ID: 2211.03024
#   -> Extracted 25 references.
# ----------------------------------------
# Processing Paper ID: 2211.03025
#   -> Extracted 71 references.
# ----------------------------------------
# Processing Paper ID: 2211.03026
#   -> Extracted 26 references.
# ----------------------------------------
# Processing Paper ID: 2211.03027
#   -> Extracted 85 references.
# ----------------------------------------
# Processing Paper ID: 2211.03028
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03029
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03030
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03031
#   -> Extracted 61 references.
# ----------------------------------------
# Processing Paper ID: 2211.03032
#   -> Extracted 75 references.
# ----------------------------------------
# Processing Paper ID: 2211.03033
#   -> Extracted 999 references.
# ----------------------------------------
# Processing Paper ID: 2211.03034
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03035
#   -> Extracted 17 references.
# ----------------------------------------
# Processing Paper ID: 2211.03036
#   -> Extracted 36 references.
# ----------------------------------------
# Processing Paper ID: 2211.03037
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03038
#   -> Extracted 27 references.
# ----------------------------------------
# Processing Paper ID: 2211.03039
#   -> Extracted 49 references.
# ----------------------------------------
# Processing Paper ID: 2211.03040
#   -> Extracted 11 references.
# ----------------------------------------
# Processing Paper ID: 2211.03041
#   -> Extracted 45 references.
# ----------------------------------------
# Processing Paper ID: 2211.03042
#   -> Extracted 54 references.
# ----------------------------------------
# Processing Paper ID: 2211.03043
#   -> Extracted 3 references.
# ----------------------------------------
# Processing Paper ID: 2211.03044
#   -> Extracted 120 references.
# ----------------------------------------
# Processing Paper ID: 2211.03045
#   -> Extracted 76 references.
# ----------------------------------------
# Processing Paper ID: 2211.03046
#   -> Extracted 661 references.
# ----------------------------------------
# Processing Paper ID: 2211.03047
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03048
#   -> Extracted 124 references.
# ----------------------------------------
# Processing Paper ID: 2211.03049
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03050
#   -> Extracted 43 references.
# ----------------------------------------
# Processing Paper ID: 2211.03051
#   -> Extracted 36 references.
# ----------------------------------------
# Processing Paper ID: 2211.03052
#   -> Extracted 85 references.
# ----------------------------------------
# Processing Paper ID: 2211.03053
#   -> Extracted 18 references.
# ----------------------------------------
# Processing Paper ID: 2211.03054
#   -> Extracted 97 references.
# ----------------------------------------
# Processing Paper ID: 2211.03055
#   -> Extracted 46 references.
# ----------------------------------------
# Processing Paper ID: 2211.03056
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03057
#   -> Extracted 21 references.
# ----------------------------------------
# Processing Paper ID: 2211.03058
#   -> Extracted 80 references.
# ----------------------------------------
# Processing Paper ID: 2211.03059
#   -> Extracted 16 references.
# ----------------------------------------
# Processing Paper ID: 2211.03060
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03061
#   -> Extracted 72 references.
# ----------------------------------------
# Processing Paper ID: 2211.03062
#   -> Extracted 57 references.
# ----------------------------------------
# Processing Paper ID: 2211.03063
#   -> Extracted 48 references.
# ----------------------------------------
# Processing Paper ID: 2211.03064
#   -> Extracted 155 references.
# ----------------------------------------
# Processing Paper ID: 2211.03065
#   -> Extracted 50 references.
# ----------------------------------------
# Processing Paper ID: 2211.03066
#   -> Extracted 111 references.
# ----------------------------------------
# Processing Paper ID: 2211.03067
#   -> Extracted 15 references.
# ----------------------------------------
# Processing Paper ID: 2211.03068
#   -> Extracted 89 references.
# ----------------------------------------
# Processing Paper ID: 2211.03069
#   -> Extracted 17 references.
# ----------------------------------------
# Processing Paper ID: 2211.03070
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03071
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03072
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03073
#   -> Extracted 32 references.
# ----------------------------------------
# Processing Paper ID: 2211.03074
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03075
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03076
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03077
#   -> Extracted 31 references.
# ----------------------------------------
# Processing Paper ID: 2211.03078
#   -> Extracted 66 references.
# ----------------------------------------
# Processing Paper ID: 2211.03079
#   -> Extracted 255 references.
# ----------------------------------------
# Processing Paper ID: 2211.03080
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03081
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03082
#   -> Extracted 209 references.
# ----------------------------------------
# Processing Paper ID: 2211.03083
#   -> Extracted 113 references.
# ----------------------------------------
# Processing Paper ID: 2211.03084
#   -> Extracted 68 references.
# ----------------------------------------
# Processing Paper ID: 2211.03085
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03086
#   -> Extracted 94 references.
# ----------------------------------------
# Processing Paper ID: 2211.03087
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03088
#   -> Extracted 59 references.
# ----------------------------------------
# Processing Paper ID: 2211.03089
#   -> Extracted 44 references.
# ----------------------------------------
# Processing Paper ID: 2211.03090
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03091
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03092
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03093
#   -> Extracted 46 references.
# ----------------------------------------
# Processing Paper ID: 2211.03094
#   -> Extracted 87 references.
# ----------------------------------------
# Processing Paper ID: 2211.03095
#   -> Extracted 18 references.
# ----------------------------------------
# Processing Paper ID: 2211.03096
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03097
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03098
#   -> Extracted 40 references.
# ----------------------------------------
# Processing Paper ID: 2211.03099
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03100
#   -> Extracted 45 references.
# ----------------------------------------
# Processing Paper ID: 2211.03101
#   -> Extracted 95 references.
# ----------------------------------------
# Processing Paper ID: 2211.03102
#   -> Extracted 73 references.
# ----------------------------------------
# Processing Paper ID: 2211.03103
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03104
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03105
#   -> Extracted 319 references.
# ----------------------------------------
# Processing Paper ID: 2211.03106
#   -> Extracted 19 references.
# ----------------------------------------
# Processing Paper ID: 2211.03107
#   -> Extracted 133 references.
# ----------------------------------------
# Processing Paper ID: 2211.03108
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03109
#   -> Extracted 29 references.
# ----------------------------------------
# Processing Paper ID: 2211.03110
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03111
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03112
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03113
#   -> Extracted 72 references.
# ----------------------------------------
# Processing Paper ID: 2211.03114
#   -> Extracted 109 references.
# ----------------------------------------
# Processing Paper ID: 2211.03115
#   -> Extracted 51 references.
# ----------------------------------------
# Processing Paper ID: 2211.03116
#   -> Extracted 316 references.
# ----------------------------------------
# Processing Paper ID: 2211.03117
#   -> Extracted 44 references.
# ----------------------------------------
# Processing Paper ID: 2211.03118
#   -> Extracted 29 references.
# ----------------------------------------
# Processing Paper ID: 2211.03119
#   -> Extracted 45 references.
# ----------------------------------------
# Processing Paper ID: 2211.03120
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03121
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03122
#   -> Extracted 8 references.
# ----------------------------------------
# Processing Paper ID: 2211.03123
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03124
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03125
#   -> Extracted 54 references.
# ----------------------------------------
# Processing Paper ID: 2211.03126
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03127
#   -> Extracted 26 references.
# ----------------------------------------
# Processing Paper ID: 2211.03128
#   -> Extracted 26 references.
# ----------------------------------------
# Processing Paper ID: 2211.03129
#   -> Extracted 28 references.
# ----------------------------------------
# Processing Paper ID: 2211.03130
#   -> Extracted 22 references.
# ----------------------------------------
# Processing Paper ID: 2211.03131
#   -> Extracted 40 references.
# ----------------------------------------
# Processing Paper ID: 2211.03132
#   -> Extracted 167 references.
# ----------------------------------------
# Processing Paper ID: 2211.03133
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03134
#   -> Extracted 72 references.
# ----------------------------------------
# Processing Paper ID: 2211.03135
#   -> Extracted 46 references.
# ----------------------------------------
# Processing Paper ID: 2211.03136
#   -> Extracted 39 references.
# ----------------------------------------
# Processing Paper ID: 2211.03137
#   -> Extracted 21 references.
# ----------------------------------------
# Processing Paper ID: 2211.03138
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03139
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03140
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03141
#   -> Extracted 33 references.
# ----------------------------------------
# Processing Paper ID: 2211.03142
#   -> Extracted 61 references.
# ----------------------------------------
# Processing Paper ID: 2211.03143
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03144
#   -> Extracted 56 references.
# ----------------------------------------
# Processing Paper ID: 2211.03145
#   -> Extracted 20 references.
# ----------------------------------------
# Processing Paper ID: 2211.03146
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03147
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03148
#   -> Extracted 39 references.
# ----------------------------------------
# Processing Paper ID: 2211.03149
#   -> Extracted 206 references.
# ----------------------------------------
# Processing Paper ID: 2211.03150
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03151
#   -> Extracted 20 references.
# ----------------------------------------
# Processing Paper ID: 2211.03152
#   -> Extracted 309 references.
# ----------------------------------------
# Processing Paper ID: 2211.03153
#   -> Extracted 26 references.
# ----------------------------------------
# Processing Paper ID: 2211.03154
#   -> Extracted 186 references.
# ----------------------------------------
# Processing Paper ID: 2211.03155
#   -> Extracted 224 references.
# ----------------------------------------
# Processing Paper ID: 2211.03156
#   -> Extracted 57 references.
# ----------------------------------------
# Processing Paper ID: 2211.03157
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03158
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03159
#   -> Extracted 104 references.
# ----------------------------------------
# Processing Paper ID: 2211.03160
#   -> Extracted 50 references.
# ----------------------------------------
# Processing Paper ID: 2211.03161
#   -> Extracted 22 references.
# ----------------------------------------
# Processing Paper ID: 2211.03162
#   -> Extracted 119 references.
# ----------------------------------------
# Processing Paper ID: 2211.03163
#   -> Extracted 705 references.
# ----------------------------------------
# Processing Paper ID: 2211.03164
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03165
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03166
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03167
#   -> Extracted 38 references.
# ----------------------------------------
# Processing Paper ID: 2211.03168
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03169
#   -> Extracted 48 references.
# ----------------------------------------
# Processing Paper ID: 2211.03170
#   -> Extracted 358 references.
# ----------------------------------------
# Processing Paper ID: 2211.03171
#   -> Extracted 26 references.
# ----------------------------------------
# Processing Paper ID: 2211.03172
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03173
#   -> Extracted 19 references.
# ----------------------------------------
# Processing Paper ID: 2211.03174
#   -> Extracted 145 references.
# ----------------------------------------
# Processing Paper ID: 2211.03175
#   -> Extracted 104 references.
# ----------------------------------------
# Processing Paper ID: 2211.03176
#   -> Extracted 90 references.
# ----------------------------------------
# Processing Paper ID: 2211.03177
#   -> Extracted 114 references.
# ----------------------------------------
# Processing Paper ID: 2211.03178
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03179
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03180
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03181
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03182
#   -> Extracted 10 references.
# ----------------------------------------
# Processing Paper ID: 2211.03183
#   -> Extracted 50 references.
# ----------------------------------------
# Processing Paper ID: 2211.03184
#   -> Extracted 23 references.
# ----------------------------------------
# Processing Paper ID: 2211.03185
#   -> Extracted 19 references.
# ----------------------------------------
# Processing Paper ID: 2211.03186
#   -> Extracted 375 references.
# ----------------------------------------
# Processing Paper ID: 2211.03187
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03188
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03189
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03190
#   -> Extracted 5 references.
# ----------------------------------------
# Processing Paper ID: 2211.03191
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03192
#   -> Extracted 71 references.
# ----------------------------------------
# Processing Paper ID: 2211.03193
#   -> Extracted 188 references.
# ----------------------------------------
# Processing Paper ID: 2211.03194
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03195
#   -> Extracted 281 references.
# ----------------------------------------
# Processing Paper ID: 2211.03196
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03197
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03198
#   -> Extracted 145 references.
# ----------------------------------------
# Processing Paper ID: 2211.03199
#   -> Extracted 71 references.
# ----------------------------------------
# Processing Paper ID: 2211.03200
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03201
#   -> Extracted 87 references.
# ----------------------------------------
# Processing Paper ID: 2211.03202
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03203
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03204
#   -> Extracted 306 references.
# ----------------------------------------
# Processing Paper ID: 2211.03205
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03206
#   -> Extracted 57 references.
# ----------------------------------------
# Processing Paper ID: 2211.03207
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03208
#   -> Extracted 201 references.
# ----------------------------------------
# Processing Paper ID: 2211.03209
#   -> Extracted 93 references.
# ----------------------------------------
# Processing Paper ID: 2211.03210
#   -> Extracted 3 references.
# ----------------------------------------
# Processing Paper ID: 2211.03211
#   -> Extracted 21 references.
# ----------------------------------------
# Processing Paper ID: 2211.03212
#   -> Extracted 14 references.
# ----------------------------------------
# Processing Paper ID: 2211.03213
#   -> Extracted 91 references.
# ----------------------------------------
# Processing Paper ID: 2211.03214
#   -> Extracted 63 references.
# ----------------------------------------
# Processing Paper ID: 2211.03215
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03216
#   -> Extracted 75 references.
# ----------------------------------------
# Processing Paper ID: 2211.03217
#   -> Extracted 232 references.
# ----------------------------------------
# Processing Paper ID: 2211.03218
#   -> Extracted 269 references.
# ----------------------------------------
# Processing Paper ID: 2211.03219
#   -> Extracted 74 references.
# ----------------------------------------
# Processing Paper ID: 2211.03220
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03221
#   -> Extracted 38 references.
# ----------------------------------------
# Processing Paper ID: 2211.03222
#   -> Extracted 41 references.
# ----------------------------------------
# Processing Paper ID: 2211.03223
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03224
#   -> Extracted 91 references.
# ----------------------------------------
# Processing Paper ID: 2211.03225
#   -> Extracted 72 references.
# ----------------------------------------
# Processing Paper ID: 2211.03226
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03227
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03228
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03229
#   -> Extracted 70 references.
# ----------------------------------------
# Processing Paper ID: 2211.03230
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03231
#   -> Extracted 198 references.
# ----------------------------------------
# Processing Paper ID: 2211.03232
#   -> Extracted 44 references.
# ----------------------------------------
# Processing Paper ID: 2211.03233
#   -> Extracted 69 references.
# ----------------------------------------
# Processing Paper ID: 2211.03234
#   -> Extracted 27 references.
# ----------------------------------------
# Processing Paper ID: 2211.03235
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03236
#   -> Extracted 61 references.
# ----------------------------------------
# Processing Paper ID: 2211.03237
#   -> Extracted 232 references.
# ----------------------------------------
# Processing Paper ID: 2211.03238
#   -> Extracted 37 references.
# ----------------------------------------
# Processing Paper ID: 2211.03239
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03240
#   -> Extracted 27 references.
# ----------------------------------------
# Processing Paper ID: 2211.03241
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03242
#   -> Extracted 50 references.
# ----------------------------------------
# Processing Paper ID: 2211.03243
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03244
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03245
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03246
#   -> Extracted 71 references.
# ----------------------------------------
# Processing Paper ID: 2211.03247
#   -> Extracted 153 references.
# ----------------------------------------
# Processing Paper ID: 2211.03248
#   -> Extracted 32 references.
# ----------------------------------------
# Processing Paper ID: 2211.03249
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03250
#   -> Extracted 31 references.
# ----------------------------------------
# Processing Paper ID: 2211.03251
#   -> Extracted 58 references.
# ----------------------------------------
# Processing Paper ID: 2211.03252
#   -> Extracted 79458 references.
# ----------------------------------------
# Processing Paper ID: 2211.03253
#   -> Extracted 58 references.
# ----------------------------------------
# Processing Paper ID: 2211.03254
#   -> Extracted 74 references.
# ----------------------------------------
# Processing Paper ID: 2211.03255
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03256
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03257
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03258
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03259
#   -> Extracted 18 references.
# ----------------------------------------
# Processing Paper ID: 2211.03260
#   -> Extracted 70 references.
# ----------------------------------------
# Processing Paper ID: 2211.03261
#   -> Extracted 27 references.
# ----------------------------------------
# Processing Paper ID: 2211.03262
#   -> Extracted 69 references.
# ----------------------------------------
# Processing Paper ID: 2211.03263
#   -> Extracted 43 references.
# ----------------------------------------
# Processing Paper ID: 2211.03264
#   -> Extracted 90 references.
# ----------------------------------------
# Processing Paper ID: 2211.03265
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03266
#   -> Extracted 36 references.
# ----------------------------------------
# Processing Paper ID: 2211.03267
#   -> Extracted 53 references.
# ----------------------------------------
# Processing Paper ID: 2211.03268
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03269
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03270
#   -> Extracted 52 references.
# ----------------------------------------
# Processing Paper ID: 2211.03271
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03272
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03273
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03274
#   -> Extracted 106 references.
# ----------------------------------------
# Processing Paper ID: 2211.03275
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03276
#   -> Extracted 19 references.
# ----------------------------------------
# Processing Paper ID: 2211.03277
#   -> Extracted 62565 references.
# ----------------------------------------
# Processing Paper ID: 2211.03278
#   -> Extracted 15 references.
# ----------------------------------------
# Processing Paper ID: 2211.03279
#   -> Extracted 30 references.
# ----------------------------------------
# Processing Paper ID: 2211.03280
#   -> Extracted 147 references.
# ----------------------------------------
# Processing Paper ID: 2211.03281
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03282
#   -> Extracted 189 references.
# ----------------------------------------
# Processing Paper ID: 2211.03283
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03284
#   -> Extracted 55 references.
# ----------------------------------------
# Processing Paper ID: 2211.03285
#   -> Extracted 81 references.
# ----------------------------------------
# Processing Paper ID: 2211.03286
#   -> Extracted 107 references.
# ----------------------------------------
# Processing Paper ID: 2211.03287
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03288
#   -> Extracted 61 references.
# ----------------------------------------
# Processing Paper ID: 2211.03289
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03290
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03291
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03292
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03293
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03294
#   -> Extracted 80 references.
# ----------------------------------------
# Processing Paper ID: 2211.03295
#   -> Extracted 204 references.
# ----------------------------------------
# Processing Paper ID: 2211.03296
#   -> Extracted 144 references.
# ----------------------------------------
# Processing Paper ID: 2211.03297
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03298
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03299
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03300
#   -> Extracted 65 references.
# ----------------------------------------
# Processing Paper ID: 2211.03301
#   -> Extracted 58 references.
# ----------------------------------------
# Processing Paper ID: 2211.03302
#   -> Extracted 68 references.
# ----------------------------------------
# Processing Paper ID: 2211.03303
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03304
#   -> Extracted 45 references.
# ----------------------------------------
# Processing Paper ID: 2211.03305
#   -> Extracted 49 references.
# ----------------------------------------
# Processing Paper ID: 2211.03306
#   -> Extracted 88 references.
# ----------------------------------------
# Processing Paper ID: 2211.03307
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03308
#   -> Extracted 90 references.
# ----------------------------------------
# Processing Paper ID: 2211.03309
#   -> Extracted 16 references.
# ----------------------------------------
# Processing Paper ID: 2211.03310
#   -> Extracted 78 references.
# ----------------------------------------
# Processing Paper ID: 2211.03311
#   -> Extracted 165 references.
# ----------------------------------------
# Processing Paper ID: 2211.03312
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03313
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03314
#   -> Extracted 64 references.
# ----------------------------------------
# Processing Paper ID: 2211.03315
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03316
#   -> Extracted 78 references.
# ----------------------------------------
# Processing Paper ID: 2211.03317
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03318
#   -> Extracted 42 references.
# ----------------------------------------
# Processing Paper ID: 2211.03319
#   -> Extracted 143 references.
# ----------------------------------------
# Processing Paper ID: 2211.03320
#   -> Extracted 63 references.
# ----------------------------------------
# Processing Paper ID: 2211.03321
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03322
#   -> Extracted 30 references.
# ----------------------------------------
# Processing Paper ID: 2211.03323
#   -> Extracted 38 references.
# ----------------------------------------
# Processing Paper ID: 2211.03324
#   -> Extracted 347 references.
# ----------------------------------------
# Processing Paper ID: 2211.03325
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03326
#   -> Extracted 14 references.
# ----------------------------------------
# Processing Paper ID: 2211.03327
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03328
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03329
#   -> Extracted 53 references.
# ----------------------------------------
# Processing Paper ID: 2211.03330
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03331
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03332
#   -> Extracted 33 references.
# ----------------------------------------
# Processing Paper ID: 2211.03333
#   -> Extracted 41 references.
# ----------------------------------------
# Processing Paper ID: 2211.03334
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03335
#   -> Extracted 32 references.
# ----------------------------------------
# Processing Paper ID: 2211.03336
#   -> Extracted 64 references.
# ----------------------------------------
# Processing Paper ID: 2211.03337
#   -> Extracted 49 references.
# ----------------------------------------
# Processing Paper ID: 2211.03338
#   -> Extracted 112 references.
# ----------------------------------------
# Processing Paper ID: 2211.03339
#   -> Extracted 52 references.
# ----------------------------------------
# Processing Paper ID: 2211.03340
#   -> Extracted 1223 references.
# ----------------------------------------
# Processing Paper ID: 2211.03341
#   -> Extracted 28 references.
# ----------------------------------------
# Processing Paper ID: 2211.03342
#   -> Extracted 49 references.
# ----------------------------------------
# Processing Paper ID: 2211.03343
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03344
#   -> Extracted 2846 references.
# ----------------------------------------
# Processing Paper ID: 2211.03345
#   -> Extracted 75 references.
# ----------------------------------------
# Processing Paper ID: 2211.03346
#   -> Extracted 57 references.
# ----------------------------------------
# Processing Paper ID: 2211.03347
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03348
#   -> Extracted 71687 references.
# ----------------------------------------
# Processing Paper ID: 2211.03349
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03350
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03351
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03352
#   -> Extracted 53 references.
# ----------------------------------------
# Processing Paper ID: 2211.03353
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03354
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03355
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03356
#   -> Extracted 81 references.
# ----------------------------------------
# Processing Paper ID: 2211.03357
#   -> Extracted 103 references.
# ----------------------------------------
# Processing Paper ID: 2211.03358
#   -> Extracted 30 references.
# ----------------------------------------
# Processing Paper ID: 2211.03359
#   -> Extracted 64 references.
# ----------------------------------------
# Processing Paper ID: 2211.03360
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03361
#   -> Extracted 86 references.
# ----------------------------------------
# Processing Paper ID: 2211.03362
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03363
#   -> Extracted 51 references.
# ----------------------------------------
# Processing Paper ID: 2211.03364
#   -> Extracted 324 references.
# ----------------------------------------
# Processing Paper ID: 2211.03365
#   -> Extracted 23 references.
# ----------------------------------------
# Processing Paper ID: 2211.03366
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03367
#   -> Extracted 14 references.
# ----------------------------------------
# Processing Paper ID: 2211.03368
#   -> Extracted 96 references.
# ----------------------------------------
# Processing Paper ID: 2211.03369
#   -> Extracted 46 references.
# ----------------------------------------
# Processing Paper ID: 2211.03370
#   -> Extracted 166 references.
# ----------------------------------------
# Processing Paper ID: 2211.03371
#   -> Extracted 79 references.
# ----------------------------------------
# Processing Paper ID: 2211.03372
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03373
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03374
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03375
#   -> Extracted 145 references.
# ----------------------------------------
# Processing Paper ID: 2211.03376
#   -> Extracted 103 references.
# ----------------------------------------
# Processing Paper ID: 2211.03377
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03378
#   -> Extracted 24 references.
# ----------------------------------------
# Processing Paper ID: 2211.03379
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03380
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03381
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03382
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03383
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03384
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03385
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03386
#   -> Extracted 47 references.
# ----------------------------------------
# Processing Paper ID: 2211.03387
#   -> Extracted 44 references.
# ----------------------------------------
# Processing Paper ID: 2211.03388
#   -> Extracted 11 references.
# ----------------------------------------
# Processing Paper ID: 2211.03389
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03390
#   -> Extracted 52 references.
# ----------------------------------------
# Processing Paper ID: 2211.03391
#   -> Extracted 1 references.
# ----------------------------------------
# Processing Paper ID: 2211.03392
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03393
#   -> Extracted 80 references.
# ----------------------------------------
# Processing Paper ID: 2211.03394
#   -> Extracted 70 references.
# ----------------------------------------
# Processing Paper ID: 2211.03395
#   -> Extracted 152 references.
# ----------------------------------------
# Processing Paper ID: 2211.03396
#   -> Extracted 154 references.
# ----------------------------------------
# Processing Paper ID: 2211.03397
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03398
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03399
#   -> Extracted 181 references.
# ----------------------------------------
# Processing Paper ID: 2211.03400
#   -> Extracted 47 references.
# ----------------------------------------
# Processing Paper ID: 2211.03401
#   -> Extracted 55 references.
# ----------------------------------------
# Processing Paper ID: 2211.03402
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03403
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03404
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03405
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03406
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03407
#   -> Extracted 69 references.
# ----------------------------------------
# Processing Paper ID: 2211.03408
#   -> Extracted 55 references.
# ----------------------------------------
# Processing Paper ID: 2211.03409
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03410
#   -> Extracted 21 references.
# ----------------------------------------
# Processing Paper ID: 2211.03411
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03412
#   -> Extracted 60 references.
# ----------------------------------------
# Processing Paper ID: 2211.03413
#   -> Extracted 59 references.
# ----------------------------------------
# Processing Paper ID: 2211.03414
#   -> Extracted 69 references.
# ----------------------------------------
# Processing Paper ID: 2211.03415
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03416
#   -> Extracted 69 references.
# ----------------------------------------
# Processing Paper ID: 2211.03417
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03418
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03419
#   -> Extracted 77 references.
# ----------------------------------------
# Processing Paper ID: 2211.03420
#   -> Extracted 131 references.
# ----------------------------------------
# Processing Paper ID: 2211.03421
#   -> Extracted 108 references.
# ----------------------------------------
# Processing Paper ID: 2211.03422
#   -> Extracted 66 references.
# ----------------------------------------
# Processing Paper ID: 2211.03423
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03424
#   -> Extracted 22 references.
# ----------------------------------------
# Processing Paper ID: 2211.03425
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03426
#   -> Extracted 92 references.
# ----------------------------------------
# Processing Paper ID: 2211.03427
#   -> Extracted 36 references.
# ----------------------------------------
# Processing Paper ID: 2211.03428
#   -> Extracted 62 references.
# ----------------------------------------
# Processing Paper ID: 2211.03429
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03430
#   -> Extracted 19 references.
# ----------------------------------------
# Processing Paper ID: 2211.03431
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03432
#   -> Extracted 28 references.
# ----------------------------------------
# Processing Paper ID: 2211.03433
#   -> Extracted 223 references.
# ----------------------------------------
# Processing Paper ID: 2211.03434
#   -> Extracted 97 references.
# ----------------------------------------
# Processing Paper ID: 2211.03435
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03436
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03437
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03438
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03439
#   -> Extracted 25 references.
# ----------------------------------------
# Processing Paper ID: 2211.03440
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03441
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03442
#   -> Extracted 44 references.
# ----------------------------------------
# Processing Paper ID: 2211.03443
#   -> Extracted 46 references.
# ----------------------------------------
# Processing Paper ID: 2211.03444
#   -> Extracted 1 references.
# ----------------------------------------
# Processing Paper ID: 2211.03445
#   -> Extracted 68 references.
# ----------------------------------------
# Processing Paper ID: 2211.03446
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03447
#   -> Extracted 1 references.
# ----------------------------------------
# Processing Paper ID: 2211.03448
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03449
#   -> Extracted 28 references.
# ----------------------------------------
# Processing Paper ID: 2211.03450
#   -> Extracted 221 references.
# ----------------------------------------
# Processing Paper ID: 2211.03451
#   -> Extracted 56 references.
# ----------------------------------------
# Processing Paper ID: 2211.03452
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03453
#   -> Extracted 34 references.
# ----------------------------------------
# Processing Paper ID: 2211.03454
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03455
#   -> Extracted 100 references.
# ----------------------------------------
# Processing Paper ID: 2211.03456
#   -> Extracted 54 references.
# ----------------------------------------
# Processing Paper ID: 2211.03457
#   -> Extracted 122 references.
# ----------------------------------------
# Processing Paper ID: 2211.03458
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03459
#   -> Extracted 111 references.
# ----------------------------------------
# Processing Paper ID: 2211.03460
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03461
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03462
#   -> Extracted 80637 references.
# ----------------------------------------
# Processing Paper ID: 2211.03463
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03464
#   -> Extracted 278 references.
# ----------------------------------------
# Processing Paper ID: 2211.03465
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03466
#   -> Extracted 29 references.
# ----------------------------------------
# Processing Paper ID: 2211.03467
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03468
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03469
#   -> Extracted 28 references.
# ----------------------------------------
# Processing Paper ID: 2211.03470
#   -> Extracted 48 references.
# ----------------------------------------
# Processing Paper ID: 2211.03471
#   -> Extracted 23 references.
# ----------------------------------------
# Processing Paper ID: 2211.03472
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03473
#   -> Extracted 86 references.
# ----------------------------------------
# Processing Paper ID: 2211.03474
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03475
#   -> Extracted 15 references.
# ----------------------------------------
# Processing Paper ID: 2211.03476
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03477
#   -> Extracted 29 references.
# ----------------------------------------
# Processing Paper ID: 2211.03478
#   -> Extracted 14 references.
# ----------------------------------------
# Processing Paper ID: 2211.03479
#   -> Extracted 187 references.
# ----------------------------------------
# Processing Paper ID: 2211.03480
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03481
#   -> Extracted 625 references.
# ----------------------------------------
# Processing Paper ID: 2211.03482
#   -> Extracted 27 references.
# ----------------------------------------
# Processing Paper ID: 2211.03483
#   -> Extracted 320 references.
# ----------------------------------------
# Processing Paper ID: 2211.03484
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03485
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03486
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03487
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03488
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03489
#   -> Extracted 71 references.
# ----------------------------------------
# Processing Paper ID: 2211.03490
#   -> Extracted 46 references.
# ----------------------------------------
# Processing Paper ID: 2211.03491
#   -> Extracted 162 references.
# ----------------------------------------
# Processing Paper ID: 2211.03492
#   -> Extracted 123 references.
# ----------------------------------------
# Processing Paper ID: 2211.03493
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03494
#   -> Extracted 39 references.
# ----------------------------------------
# Processing Paper ID: 2211.03495
#   -> Extracted 52 references.
# ----------------------------------------
# Processing Paper ID: 2211.03496
#   -> Extracted 35 references.
# ----------------------------------------
# Processing Paper ID: 2211.03497
#   -> Extracted 76 references.
# ----------------------------------------
# Processing Paper ID: 2211.03498
#   -> Extracted 0 references.
# ----------------------------------------
# Processing Paper ID: 2211.03499
#   -> Extracted 0 references.
# ----------------------------------------
#
# Example Output for 2211.03003 (First 5 refs):
# [
#     {
#         "id": "zhao2019ordinal",
#         "title": "Ordinal multi-task part segmentation with recurrent prior generation",
#         "authors": [
#             "Zhao, Yifan",
#             "Li, Jia",
#             "Zhang, Yu",
#             "Song, Yafei",
#             "Tian, Yonghong"
#         ],
#         "year": "2019",
#         "source_type": "bib"
#     },
#     {
#         "id": "tsogkas2015deep",
#         "title": "Deep learning for semantic part segmentation with high-level guidance",
#         "authors": [
#             "Tsogkas, Stavros",
#             "Kokkinos, Iasonas",
#             "Papandreou, George",
#             "Vedaldi, Andrea"
#         ],
#         "year": "2015",
#         "source_type": "bib"
#     },
#     {
#         "id": "pascal-voc-2010",
#         "title": "The {PASCAL} {V}isual {O}bject {C}lasses {C}hallenge 2010 {(VOC2010)} {R}esults",
#         "authors": [
#             "Everingham, M.",
#             "Van~Gool, L.",
#             "Williams, C. K. I.",
#             "Winn, J.",
#             "Zisserman, A."
#         ],
#         "year": "",
#         "source_type": "bib"
#     },
#     {
#         "id": "lin2014microsoft",
#         "title": "Microsoft coco: Common objects in context",
#         "authors": [
#             "Lin, Tsung-Yi",
#             "Maire, Michael",
#             "Belongie, Serge",
#             "Hays, James",
#             "Perona, Pietro",
#             "Ramanan, Deva",
#             "Doll{\\'a}r, Piotr",
#             "Zitnick, C Lawrence"
#         ],
#         "year": "2014",
#         "source_type": "bib"
#     }
# ]

# %%
# DEBUG
debug_dir = os.path.join('..', 'output', 'debug_extracted_refs')
os.makedirs(debug_dir, exist_ok=True)

# Select the paper you want to check (using the sample_pid from your previous cell)
target_pid = sample_pid 
data_to_save = all_papers_refs[target_pid]

# Define the filename
output_filename = f"{target_pid}_extracted_refs_2.json"
output_path = os.path.join(debug_dir, output_filename)

# Save to JSON
with open(output_path, 'w', encoding='utf-8') as f:
    json.dump(data_to_save, f, indent=4, ensure_ascii=False)

print(f"Successfully saved extracted references for {target_pid} to:")
print(os.path.abspath(output_path))
# Out:
# Successfully saved extracted references for 2211.03003 to:
# /Users/thomas200905/Documents/Thomas/HCMUS/Third Year/Semester 7/Intro to Data Science/Milestones/MS02/output/debug_extracted_refs/2211.03003_extracted_refs_2.json

# %% [markdown]
# ### 1.2 From references.json

# %%
def load_references_json_file(paper_id, data_path):
    if not data_path:
        json_path = os.path.join(AUTO_DATA_PATH, paper_id, 'references.json')
    else:
        json_path = os.path.join(data_path, paper_id, 'references.json')
    
    if not os.path.exists(json_path):
        print(f"references.json not found for paper {paper_id}")
        return []
    
    try:
        with open(json_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
            
        if data is None or not isinstance(data, dict):
            print(f"Warning: references.json for {paper_id} is empty or invalid format.")
            return []
            
    except json.JSONDecodeError:
        print(f"Could not decode JSON for paper {paper_id}")
        return []
        
    target_references = []
    
    for arxiv_id, metadata in data.items():
        
        title = metadata.get('title', "")
        authors = metadata.get('authors', [])
        date_str = metadata.get('submission_date', "")
        year = ""

        if date_str:
            year = date_str.split('-')[0]
            
        target_references.append({
            "id": arxiv_id,             
            "title": title,
            "authors": authors,
            "year": year,
            "source_type": "references_json"
        })
        
    return target_references

# %%
all_papers_target_refs = {}

for pid in paper_ids:
    targets = load_references_json_file(pid, AUTO_DATA_PATH)
    all_papers_target_refs[pid] = targets
    

print(f"\nLoaded targets for {len(all_papers_target_refs)} papers.")

# DEBUG
if len(paper_ids) > 0:
    sample_pid = paper_ids[1]
    if all_papers_target_refs[sample_pid]:
        print(f"\nExample Target Entry for {sample_pid}:")
        print(json.dumps(all_papers_target_refs[sample_pid][0], indent=4))
# Out:
# Warning: references.json for 2211.03130 is empty or invalid format.
# Warning: references.json for 2211.03225 is empty or invalid format.
# Warning: references.json for 2211.03324 is empty or invalid format.
# Warning: references.json for 2211.03333 is empty or invalid format.
# Warning: references.json for 2211.03339 is empty or invalid format.
# Warning: references.json for 2211.03403 is empty or invalid format.
# Warning: references.json for 2211.03406 is empty or invalid format.
# Warning: references.json for 2211.03432 is empty or invalid format.
# Warning: references.json for 2211.03446 is empty or invalid format.
#
# Loaded targets for 498 papers.
#
# Example Target Entry for 2211.03002:
# {
#     "id": "2011.09318",
#     "title": "Analysis of Cryptocurrency Transactions from a Network Perspective: An Overview",
#     "authors": [
#         "Jiajing Wu",
#         "Jieli Liu",
#         "Yijing Zhao",
#         "Zibin Zheng"
#     ],
#     "year": "2020",
#     "source_type": "references_json"
# }

# %% [markdown]
# ## 2. Clean references

# %%
STOP_WORDS = {
    'a', 'an', 'the', 'and', 'or', 'of', 'to', 'in', 'on', 'at', 'by', 'for', 
    'with', 'from', 'as', 'is', 'are', 'was', 'were', 'be', 'been', 'this', 'that'
}

# %%
def clean_text(text):
    if not text:
        return ""
    
    # to lowercase
    text = text.lower()
    
    # remove punctuation
    text = re.sub(r'[^a-z0-9\s]', ' ', text)
    
    # filter stop words
    tokens = text.split()
    clean_tokens = [t for t in tokens if t not in STOP_WORDS]
    
    return " ".join(clean_tokens)

def tokenize_author_list(authors_list):
    if not authors_list:
        return set()
    
    all_authors = " ".join(authors_list)
    all_authors = all_authors.lower()
    all_authors = re.sub(r'[^a-z\s]', ' ', all_authors)
    
    # separate all author string into tokens
    tokens = set(all_authors.split())
    
    return tokens

# %%
def clean_references(reference_list):
    for reference in reference_list:
        reference['clean_title'] = clean_text(reference.get('title', ''))
        reference['clean_author_tokens'] = tokenize_author_list(reference.get('authors', []))
        
    return reference_list

# %%
print("Cleaning extracted references (Source)...")
for pid in all_papers_refs:
    clean_references(all_papers_refs[pid])

print("Cleaning target references (Target)...")
for pid in all_papers_target_refs:
    clean_references(all_papers_target_refs[pid])
    
print("Cleaning completed")
# Out:
# Cleaning extracted references (Source)...
# Cleaning target references (Target)...
# Cleaning completed

# %%
# DEBUG
if len(paper_ids) > 0:
    sample_pid = paper_ids[0]
    
    # check source (bib)
    if all_papers_refs[sample_pid]:
        ref = all_papers_refs[sample_pid][0]
        print(f"--- Source (BibTeX) ---")
        print(f"Original Title:  {ref['title']}")
        print(f"Clean Title:     {ref['clean_title']}")
        print(f"Original Authors:{ref['authors']}")
        print(f"Author Tokens:   {ref['clean_author_tokens']}")
        print("")

    # check target (json)
    if all_papers_target_refs[sample_pid]:
        target = all_papers_target_refs[sample_pid][0]
        print(f"--- Target (JSON) ---")
        print(f"Original Title:  {target['title']}")
        print(f"Clean Title:     {target['clean_title']}")
        print(f"Original Authors:{target['authors']}")
        print(f"Author Tokens:   {target['clean_author_tokens']}")
# Out:
# --- Source (BibTeX) ---
# Original Title:  Information Visualization, Visual Data Mining, and Its Application to Drug Design
# Clean Title:     information visualization visual data mining its application drug design
# Original Authors:['Georges Grinstein', 'Daniel Keim', 'Matthew Ward']
# Author Tokens:   {'matthew', 'keim', 'daniel', 'georges', 'grinstein', 'ward'}
#
# --- Target (JSON) ---
# Original Title:  PoVRPoint: Authoring Presentations in Mobile Virtual Reality
# Clean Title:     povrpoint authoring presentations mobile virtual reality
# Original Authors:['Verena Biener', 'Travis Gesslein', 'D. Schneider', 'Felix Kawala', 'Alexander Otte', 'P. Kristensson', 'M. Pahud', 'E. Ofek', 'Cuauhtli Campos', 'Matjavz Kljun', 'Klen vCopivc Pucihar', 'Jens Grubert']
# Author Tokens:   {'cuauhtli', 'otte', 'campos', 'pucihar', 'm', 'jens', 'schneider', 'd', 'kristensson', 'grubert', 'alexander', 'gesslein', 'e', 'felix', 'verena', 'kljun', 'biener', 'travis', 'klen', 'pahud', 'vcopivc', 'ofek', 'p', 'matjavz', 'kawala'}

# %% [markdown]
# ## 3. Match reference ID

# %%
def generate_automatic_labels(source_reference_list, target_reference_list):
    target_map = {}
    for reference in target_reference_list:
        # avoid titles that are too short, short titles doesnt contain enough info
        if reference['clean_title'] and len(reference['clean_title']) > 10: 
            target_map[reference['clean_title']] = reference['id']
            
    matches = {}
    
    for reference in source_reference_list:
        s_title = reference['clean_title']
        s_id = reference['id']
        
        if not s_title or len(s_title) <= 10:
            continue
            
        if s_title in target_map:
            matched_target_reference = target_map[s_title]
            matches[s_id] = matched_target_reference
            
    return matches

# %%
all_papers_gt = {} # ground truth for all papers
total_matches = 0
total_refs = 0

print("Generating Automatic Ground Truth...")

for pid in paper_ids:
    sources = all_papers_refs[pid]
    targets = all_papers_target_refs[pid]
    
    paper_matches = generate_automatic_labels(sources, targets)
    all_papers_gt[pid] = paper_matches
    
    n_source = len(sources)
    n_match = len(paper_matches)
    total_refs += n_source
    total_matches += n_match

print("-" * 40)
print(f"Total References Processed: {total_refs}")
print(f"Total Automatic Matches:    {total_matches}")
print(f"Global Match Rate:          {total_matches/total_refs:.1%}")
print("-" * 40)
# Out:
# Generating Automatic Ground Truth...
# ----------------------------------------
# Total References Processed: 399500
# Total Automatic Matches:    4471
# Global Match Rate:          1.1%
# ----------------------------------------

# %% [markdown]
# ## 4. Save ground truth

# %%
debug_gt_dir = os.path.join('..', 'data', 'processed','ground_truth')
os.makedirs(debug_gt_dir, exist_ok=True)

filename = "auto.json"
output_gt_path = os.path.join(debug_gt_dir, filename)

with open(output_gt_path, 'w', encoding='utf-8') as f:
    json.dump(all_papers_gt, f, indent=4, ensure_ascii=False)

print(f"Saved automatic labels to:")
print(os.path.abspath(output_gt_path))
# Out:
# Saved automatic labels to:
# /Users/thomas200905/Documents/Thomas/HCMUS/Third Year/Semester 7/Intro to Data Science/Milestones/MS02/data/processed/ground_truth/auto.json
