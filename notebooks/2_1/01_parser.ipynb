# %%
# # Notebook 1: Hierarchical Parsing & Standardization
# 
# **Objectives:**
# 1. Parse raw LaTeX into a structured JSON hierarchy.
# 2. Normalize text and math formulas.
# 3. Extract and deduplicate references (`refs.bib`), filtering only those cited in the text.
# 4. Generate unique IDs (Hashes) for content to handle deduplication across versions.

import os, re, json, hashlib, shutil, sys
from pylatexenc.latexwalker import LatexWalker, LatexEnvironmentNode, LatexCharsNode, \
                                    LatexGroupNode, LatexMathNode, LatexMacroNode, LatexCommentNode, LatexSpecialsNode
from concurrent.futures import ThreadPoolExecutor, as_completed
import shutil

RAW_DATA_PATH = os.path.join('..', '..', 'data', '2_2','raw', 'auto') 
OUTPUT_PATH = os.path.join('..', '..', 'data', '2_2', 'processed', 'parsed', 'auto')

# RAW_DATA_PATH = os.path.join("..", "data",'testing', 'input') 
# OUTPUT_PATH = os.path.join("..", 'data', 'testing', 'output')

LEVELS = {
    "root": 0,
    "abstract": 1,
    "section": 2,
    "subsection": 3,
    "subsubsection": 4,
    "paragraph": 5,
    "subparagraph": 6,
    "itemize": 7,   
    "enumerate": 7,
    "item": 8,
    "leaf": 9       # Sentences, Figures, Tables, Formulas
}

print(f"Input: {os.path.abspath(RAW_DATA_PATH)}")
print(f"Output: {os.path.abspath(OUTPUT_PATH)}")
# Out:
# Input: /Users/thomas200905/Documents/Thomas/HCMUS/Third Year/Semester 7/Intro to Data Science/Milestones/MS02/IntroDS_Milestone2/data/2_2/raw/auto
# Output: /Users/thomas200905/Documents/Thomas/HCMUS/Third Year/Semester 7/Intro to Data Science/Milestones/MS02/IntroDS_Milestone2/data/2_2/processed/parsed/auto

# %%
def clean_latex_string(text):
    if not text:
        return ""
    text = re.sub(r'\\bibinfo\{.*?\}\{(.*?)\}', r'\1', text)
    text = re.sub(r'\\[a-zA-Z]+\{(.*?)\}', r'\1', text)
    text = text.replace('\n', ' ').strip()
    text = re.sub(r'\s+', ' ', text)
    return text

def clean_body_text(text):
    if not text:
        return ""
    cmds_to_remove = r'\\(centering|newpage|clearpage|tableofcontents|maketitle|hrule|vfill)'
    text = re.sub(cmds_to_remove, '', text)
    text = re.sub(r'\\[hv]space\{.*?\}', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def normalize_math(latex_code, is_inline=True):
    clean = latex_code.strip()
    clean = re.sub(r'^\\\(|\\\)$', '', clean)
    clean = re.sub(r'^\\\[|\\\]$', '', clean)
    clean = re.sub(r'^(\$)|(\$)$', '', clean)
    
    if is_inline:
        return f"${clean}$"
    else:
        if clean.startswith(r'\begin'):
            return clean
        return f"\\begin{{equation}}{clean}\\end{{equation}}"

def generate_id(content, paper_id):
    if not content: return None
    hash_obj = hashlib.md5(content.encode('utf-8'))
    return f"{paper_id}_{hash_obj.hexdigest()}"

# Avoids splitting on "et al.", "Fig.", "Eq."
SENTENCE_PATTERN = re.compile(r"(?<!\b[A-Z])(?<![Ee][Tt] [Aa][Ll])(?<![Ff][Ii][Gg])(?<![Ee][Qq])\.\s+(?=[A-Z])")

def split_sentences(text):
    if not text: return []
    sentences = SENTENCE_PATTERN.split(text)
    return [s.strip() for s in sentences if s.strip()]

# %%
def get_field(field_name, entry):
    pat_braces = re.compile(fr'\b{field_name}\s*=\s*\{{((?:[^{{}}]|\{{[^{{}}]*\}})*)\}}', re.IGNORECASE | re.DOTALL)
    match = pat_braces.search(entry)
    if match: return match.group(1)
    pat_quotes = re.compile(fr'\b{field_name}\s*=\s*\"(.*?)\"', re.IGNORECASE | re.DOTALL)
    match = pat_quotes.search(entry)
    if match: return match.group(1)
    return None

ADDITIONAL_FIELDS = [
    'journal', 'booktitle', 'volume', 'number', 'pages', 
    'publisher', 'organization', 'school', 'institution', 
    'doi', 'url', 'issn', 'isbn', 'month', 'editor', 'series'
]

def extract_from_bib(file_content):
    references = []
    raw_entries = re.split(r'^@', file_content, flags=re.MULTILINE)
    
    for entry in raw_entries:
        entry = entry.strip()
        if not entry or entry.startswith('%'): continue
            
        key_match = re.search(r'^(\w+)\s*\{\s*([^,]+),', entry)
        if not key_match: continue
            
        ref_type = key_match.group(1)
        ref_id = key_match.group(2).strip()

        if ref_type.lower() in ['string', 'comment', 'preamble']: continue
        ref_data = {
            "id": ref_id,
            "type": ref_type,
            "title": "",
            "authors": [],
            "year": "",
            "source_type": "bib"
        }
        raw_authors = get_field('author', entry)
        if raw_authors:
            cleaned_auth = clean_latex_string(raw_authors)
            ref_data["authors"] = [a.strip() for a in cleaned_auth.split(' and ')]
            
        ref_data["title"] = clean_latex_string(get_field('title', entry))
        ref_data["year"] = get_field('year', entry) or ""
        
        for field in ADDITIONAL_FIELDS:
            val = get_field(field, entry)
            if val:
                ref_data[field] = clean_latex_string(val)

        references.append(ref_data)
    return references

def extract_from_bibitem(file_content):
    bib_section = re.search(r'\\begin\{thebibliography\}.*?\n(.*?)\\end\{thebibliography\}', file_content, re.DOTALL)
    if not bib_section:
        bib_section = re.search(r'\\begin\{references\}.*?\n(.*?)\\end\{references\}', file_content, re.DOTALL)
    
    content_to_parse = bib_section.group(1) if bib_section else file_content
    raw_items = re.split(r'\\bibitem', content_to_parse)
    
    references = []
    pat_bibinfo = re.compile(r'\\bibinfo\{(.*?)\}\{((?:[^{}]|\{[^{}]*\})*)\}', re.DOTALL | re.IGNORECASE)
    pat_italic = re.compile(r'(?:\{\\em\s+|\\emph\{|\\textit\{)((?:[^{}]|\{[^{}]*\})*)\}', re.IGNORECASE | re.DOTALL)
    pat_quotes = re.compile(r'``(.*?)''|"(.*?)"', re.DOTALL)
    pat_year = re.compile(r'\((\d{4})\)')

    for item in raw_items:
        if not item.strip():
            continue
        
        id_match = re.search(r'^\{([^}]+)\}', item.strip())
        if not id_match: continue
        ref_id = id_match.group(1).strip()
        id_end_idx = item.find('}') + 1
        
        ref_data = {
            "id": ref_id, "title": "", "authors": [], "year": "", 
            "journal": "", "source_type": "bibitem"
        }
        
        if r'\bibinfo' in item:
            for key, value in pat_bibinfo.findall(item):
                key = key.lower()
                val = clean_latex_string(value)
                if key == 'author': ref_data['authors'].append(val)
                else: ref_data[key] = val
            
        else:
            y_match = pat_year.search(item)
            if y_match: ref_data['year'] = y_match.group(1)
            quote_match = pat_quotes.search(item)
            italic_match = pat_italic.search(item)
            if quote_match and (not italic_match or quote_match.start() < italic_match.start()):
                raw_title = quote_match.group(1) or quote_match.group(2)
                ref_data['title'] = clean_latex_string(raw_title)
                
                title_start = quote_match.start()
                if title_start > id_end_idx:
                    raw_auth = item[id_end_idx:title_start]
                    ref_data['authors'] = [clean_latex_string(raw_auth).rstrip(',').strip()]
                    
                if italic_match:
                    ref_data['journal'] = clean_latex_string(italic_match.group(1))

            elif italic_match:
                italic_text = clean_latex_string(italic_match.group(1))
                
                italic_start = italic_match.start()
                pre_text = item[id_end_idx:italic_start].strip()
                if pre_text.endswith(',') or pre_text.endswith('.'):
                    pre_text = pre_text[:-1]
                
                last_comma = pre_text.rfind(',')
                
                if last_comma != -1:
                    potential_author = pre_text[:last_comma]
                    potential_title = pre_text[last_comma+1:]
                    
                    # too short, the comma was part of the name
                    if len(potential_title.strip()) < 5:
                        # case: Book. Italic = Title.
                        ref_data['title'] = italic_text
                        ref_data['authors'] = [clean_latex_string(pre_text)]
                    else:
                        # case: Article. Plain = Title, Italic = Journal.
                        ref_data['title'] = clean_latex_string(potential_title)
                        ref_data['authors'] = [clean_latex_string(potential_author)]
                        ref_data['journal'] = italic_text
                else:
                    # case: "Author \emph{BookTitle}"
                    ref_data['title'] = italic_text
                    ref_data['authors'] = [clean_latex_string(pre_text)]
            else:
                ref_data['title'] = clean_latex_string(item[id_end_idx:])

        references.append(ref_data)
    return references

def get_ref_fingerprint(ref):
    title = ref.get('title', '')
    if not title: return None 
    
    clean_title = re.sub(r'[^a-z0-9]', '', title.lower())
    
    year = ref.get('year', '')
    clean_year = re.sub(r'[^0-9]', '', str(year))
    
    return f"{clean_title}_{clean_year}"

def unionize_refs(target, source):
    for key, value in source.items():
        if key not in target or not target[key]:
            target[key] = value
    return target

def process_batch_get_paper_refs(extracted_list, content_map, key_map):
    for ref in extracted_list:
        ref_id = ref['id']
        fp = get_ref_fingerprint(ref)
        
        if not fp: 
            fp = f"ID_{ref_id}"

        if fp in content_map:
            master_ref = content_map[fp]
            unionize_refs(master_ref, ref)
            key_map[ref_id] = master_ref['id']
        else:
            content_map[fp] = ref
            key_map[ref_id] = ref_id

def get_paper_references(paper_id, root_path):
    paper_path = os.path.join(root_path, paper_id)
    content_map = {}
    key_map = {} 
    
    for root, _, files in os.walk(paper_path):
        for file in files:
            if file.endswith(".bib"):
                try:
                    with open(os.path.join(root, file), 'r', encoding='utf-8', errors='ignore') as f:
                        refs = extract_from_bib(f.read())
                        process_batch_get_paper_refs(refs, content_map, key_map)
                except:
                    pass
    
    for root, _, files in os.walk(paper_path):
        for file in files:
            if file.endswith(".tex"):
                try:
                    with open(os.path.join(root, file), 'r', encoding='utf-8', errors='ignore') as f:
                        content = f.read()
                        if "bibitem" in content:
                            refs = extract_from_bibitem(content)
                            process_batch_get_paper_refs(refs, content_map, key_map)
                except:
                    pass
                
    return list(content_map.values()), key_map

# %%
def parse_latex_nodes(nodes, base_dir, current_level_name="leaf"):
    elements = []
    citations = set()
    
    for node in nodes:
        if node is None or isinstance(node, LatexCommentNode):
            continue

        if isinstance(node, LatexCharsNode):
            text = clean_body_text(node.chars)
            if text:
                for s in split_sentences(text):
                    elements.append({
                        'content': s,
                        'level': LEVELS['leaf'],
                        'type': 'sentence'
                    })

        elif isinstance(node, LatexMathNode):
            is_inline = (node.displaytype == 'inline')
            norm_math = normalize_math(node.latex_verbatim(), is_inline)
            elements.append({
                'content': norm_math,
                'level': LEVELS['leaf'],
                'type': 'math'
            })

        elif isinstance(node, LatexEnvironmentNode):
            env = node.environmentname.lower()
            if env in ['thebibliography', 'references']:
                continue
            if env in ['figure', 'table', 'figure*', 'table*']:
                elements.append({
                    'content': node.latex_verbatim(), 
                    'level': LEVELS['leaf'],
                    'type': 'figure'
                })
            elif env in ['itemize', 'enumerate']:
                elements.append({
                    'content': f"List ({env})", 
                    'level': LEVELS['itemize'],
                    'type': env
                })
                sub_elems, sub_cites = parse_latex_nodes(node.nodelist, base_dir, 'item')
                elements.extend(sub_elems)
                citations.update(sub_cites)
            elif env in ['equation', 'align', 'equation*', 'align*']:
                norm_math = normalize_math(node.latex_verbatim(), is_inline=False)
                elements.append({
                    'content': norm_math,
                    'level': LEVELS['leaf'],
                    'type': 'math_block'
                })
                
            else:
                if env == 'abstract':
                    elements.append({'content': 'Abstract', 'level': LEVELS['abstract'], 'type': 'section'})
                
                sub_elems, sub_cites = parse_latex_nodes(node.nodelist, base_dir, env)
                elements.extend(sub_elems)
                citations.update(sub_cites)

        elif isinstance(node, LatexMacroNode):
            name = node.macroname
            
            if name == 'bibliography':
                continue

            if name in ['section', 'subsection', 'subsubsection', 'paragraph', 'subparagraph']:
                if node.nodeargd and node.nodeargd.argnlist:
                    title = ""
                    for arg in node.nodeargd.argnlist:
                        if not arg:
                            continue
                        
                        if hasattr(arg, 'nodelist'):
                            title += "".join([n.chars for n in arg.nodelist if isinstance(n, LatexCharsNode)])
                        
                        elif isinstance(arg, LatexCharsNode):
                            title += arg.chars
                    
                    elements.append({
                        'content': clean_body_text(title),
                        'level': LEVELS.get(name, LEVELS['section']),
                        'type': name
                    })

            elif name == 'item':
                elements.append({
                    'content': "Item", 
                    'level': LEVELS['item'],
                    'type': 'item'
                })
            elif name in ['cite', 'citep', 'citet', 'citeauthor']:
                if node.nodeargd and node.nodeargd.argnlist:
                    for arg in node.nodeargd.argnlist:
                        if not arg:
                            continue

                        if hasattr(arg, 'nodelist'):
                            for n in arg.nodelist:
                                if isinstance(n, LatexCharsNode):
                                    keys = n.chars.split(',')
                                    for k in keys: citations.add(k.strip())
                        elif isinstance(arg, LatexCharsNode):
                            keys = arg.chars.split(',')
                            for k in keys: citations.add(k.strip())

                elements.append({
                    'content': node.latex_verbatim(), 
                    'level': LEVELS['leaf'],
                    'type': 'citation'
                })

            elif name in ['input', 'include']:
                if node.nodeargd and node.nodeargd.argnlist:
                    arg_node = node.nodeargd.argnlist[0]
                    fname = ""
                    if hasattr(arg_node, 'nodelist') and arg_node.nodelist:
                         if isinstance(arg_node.nodelist[0], LatexCharsNode):
                             fname = arg_node.nodelist[0].chars
                    elif isinstance(arg_node, LatexCharsNode):
                        fname = arg_node.chars
                        
                    if fname:
                        if not fname.endswith('.tex'):
                            fname += '.tex'
                        
                        full_path = os.path.join(base_dir, fname)
                        if os.path.exists(full_path):
                            print(f"    -> Parsing input: {fname}")
                            try:
                                with open(full_path, 'r', encoding='latin-1') as f:
                                    sub_nodes, _, _ = LatexWalker(f.read()).get_latex_nodes()
                                    sub_elems, sub_cites = parse_latex_nodes(sub_nodes, base_dir, current_level_name)
                                    elements.extend(sub_elems)
                                    citations.update(sub_cites)
                            except Exception as e:
                                print(f"    [Error] Failed to parse input {fname}: {e}")

    return elements, citations

# %%
def build_hierarchy_tree(flat_elements, paper_id, global_elements_store):
    hierarchy = {}
    
    root_content = f"Document Root {paper_id}"
    root_id = generate_id(root_content, paper_id)
    global_elements_store[root_id] = root_content
    
    stack = [(0, root_id)]
    
    for item in flat_elements:
        content = item['content']
        level = item['level']
        if not content:
            continue
        
        node_id = generate_id(content, paper_id)
        global_elements_store[node_id] = content

        while stack and stack[-1][0] >= level:
            stack.pop()
            
        if stack:
            parent_id = stack[-1][1]
            hierarchy[node_id] = parent_id
        
        if level < LEVELS['leaf']:
            stack.append((level, node_id))
            
    return hierarchy

def write_refs_bib(references, output_path):
    internal_keys = {'id', 'type', 'source_type', 'authors'}
    
    with open(output_path, 'w', encoding='utf-8') as f:
        for ref in references:
            entry_type = ref.get('type', 'misc').lower()
            key = ref.get('id', 'unknown')
            
            lines = [f"@{entry_type}{{{key},"]
            
            if ref.get('authors'):
                auth_str = " and ".join(ref['authors'])
                lines.append(f"  author = {{{auth_str}}},")
            
            for k, v in ref.items():
                if k not in internal_keys and v:
                    lines.append(f"  {k} = {{{v}}},")
                
            lines.append("}\n")
            f.write("\n".join(lines))

# %%
def process_paper(paper_id):
    source_dir = os.path.join(RAW_DATA_PATH, paper_id)
    target_dir = os.path.join(OUTPUT_PATH, paper_id)
    os.makedirs(target_dir, exist_ok=True)

    for fname in ['metadata.json', 'references.json']:
        src = os.path.join(source_dir, fname)
        if os.path.exists(src):
            shutil.copy(src, os.path.join(target_dir, fname))
            
    all_raw_refs, key_map = get_paper_references(paper_id, RAW_DATA_PATH)
    ref_lookup = {r['id']: r for r in all_raw_refs}
    
    tex_root = os.path.join(source_dir, 'tex')
    if not os.path.exists(tex_root):
        return

    global_elements = {}
    hierarchy_output = {}
    all_cited_keys = set()
    
    for v_folder in sorted(os.listdir(tex_root)):
        full_v_path = os.path.join(tex_root, v_folder)
        if not os.path.isdir(full_v_path):
            continue

        main_file = None
        for f in os.listdir(full_v_path):
            if f.endswith('.tex'):
                try:
                    with open(os.path.join(full_v_path, f), 'r', encoding='latin-1') as tf:
                        if r'\documentclass' in tf.read():
                            main_file = f
                            break
                except:
                    pass
        
        if not main_file:
            continue
        
        with open(os.path.join(full_v_path, main_file), 'r', encoding='latin-1') as f:
            w = LatexWalker(f.read())
            nodes, _, _ = w.get_latex_nodes()
            
        elements, citations = parse_latex_nodes(nodes, full_v_path)
        
        normalized_citations = set()
        for c in citations:
            master_key = key_map.get(c, c)
            normalized_citations.add(master_key)
            
        all_cited_keys.update(normalized_citations)

        version_key = v_folder.split('v')[-1]
        hierarchy_output[version_key] = build_hierarchy_tree(elements, paper_id, global_elements)

    final_json = {"elements": global_elements, "hierarchy": hierarchy_output}
    with open(os.path.join(target_dir, 'hierarchy.json'), 'w', encoding='utf-8') as f:
        json.dump(final_json, f, indent=4, ensure_ascii=False)
        
    final_refs = []
    for k in all_cited_keys:
        if k in ref_lookup:
            final_refs.append(ref_lookup[k])
    
    if not final_refs and all_raw_refs:
        final_refs = all_raw_refs
        
    write_refs_bib(final_refs, os.path.join(target_dir, 'refs.bib'))
    
    print(f"[{paper_id}] Done. Elements: {len(global_elements)}, Refs: {len(final_refs)}")

paper_ids = [d for d in os.listdir(RAW_DATA_PATH) if os.path.isdir(os.path.join(RAW_DATA_PATH, d))]
paper_ids.sort()

MAX_WORKERS = 30     
TIMEOUT_SECONDS = 30     # Max time per paper (in seconds)
FAILED_LOG_FILE = "failed_ids.txt"

def cleanup_failed_paper(paper_id):
    target_dir = os.path.join(OUTPUT_PATH, paper_id)
    if os.path.exists(target_dir):
        try:
            shutil.rmtree(target_dir)
            print(f"  [Cleanup] Removed partial folder for {paper_id}")
        except Exception as e:
            print(f"  [Cleanup Error] Could not delete {target_dir}: {e}")

paper_ids = [d for d in os.listdir(RAW_DATA_PATH) if os.path.isdir(os.path.join(RAW_DATA_PATH, d))]
paper_ids.sort()

print(f"Starting parallel processing of {len(paper_ids)} papers...")
print(f"Configuration: {MAX_WORKERS} threads, {TIMEOUT_SECONDS}s timeout.")
print("-" * 50)

failed_ids = []

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    future_to_pid = {executor.submit(process_paper, pid): pid for pid in paper_ids}
    
    for future in future_to_pid:
        pid = future_to_pid[future]
        try:
            future.result(timeout=TIMEOUT_SECONDS)
        except TimeoutError:
            print(f"\n[TIMEOUT] Paper {pid} exceeded {TIMEOUT_SECONDS}s.")
            failed_ids.append(pid)
            cleanup_failed_paper(pid)
        except Exception as e:
            print(f"\n[CRITICAL ERROR] Failed to process {pid}: {e}")
            failed_ids.append(pid)
            cleanup_failed_paper(pid)

print("-" * 50)
print(f"Processing Complete.")
print(f"Total Failed/Timed-out: {len(failed_ids)}")

if failed_ids:
    with open(FAILED_LOG_FILE, "w") as f:
        f.write("\n".join(failed_ids))
    print(f"List of failed IDs saved to {FAILED_LOG_FILE}")
# Out:
# Starting parallel processing of 310 papers...
# Configuration: 30 threads, 30s timeout.
# --------------------------------------------------
# [2211.03007] Done. Elements: 0, Refs: 0
# [2211.03010] Done. Elements: 0, Refs: 0
# [2211.03028] Done. Elements: 0, Refs: 0
#     -> Parsing input: content/1-introduction.tex
# [2211.03012] Done. Elements: 372, Refs: 43
#     -> Parsing input: content/2-related-work.tex
# [2211.03030] Done. Elements: 0, Refs: 0
# [2211.03014] Done. Elements: 331, Refs: 30
# [2211.03016] Done. Elements: 121, Refs: 6
# [2211.03026] Done. Elements: 310, Refs: 26
# [2211.03027] Done. Elements: 269, Refs: 23
# [2211.03005] Done. Elements: 331, Refs: 3
#     -> Parsing input: content/3-method.tex
#     -> Parsing input: 01-introduction.tex
#     -> Parsing input: math_commands.tex
#     -> Parsing input: intro.tex
# [2211.03018] Done. Elements: 460, Refs: 25
# [2211.03025] Done. Elements: 303, Refs: 39
#     -> Parsing input: related.tex
#     -> Parsing input: content/4-evaluation.tex
#     -> Parsing input: 02-related-work.tex
# [2211.03022] Done. Elements: 614, Refs: 31
# [2211.03019] Done. Elements: 533, Refs: 34
# [2211.03024] Done. Elements: 553, Refs: 25
#     -> Parsing input: methodology.tex
#     -> Parsing input: result1.tex
#     -> Parsing input: content/5-discussion.tex
# [2211.03034] Done. Elements: 0, Refs: 0
#     -> Parsing input: 03-dataset.tex
#     -> Parsing input: sections/introduction.tex
#     -> Parsing input: content/6-conclusions.tex
# [2211.03006] Done. Elements: 1436, Refs: 39
#     -> Parsing input: sections/model2.tex
#     -> Parsing input: appendix.tex    -> Parsing input: definitions.tex
#
#     -> Parsing input: abstract.tex
#     -> Parsing input: content/8-appendix.tex
# [2211.03003] Done. Elements: 696, Refs: 68
#     -> Parsing input: 04-descriptive-analysis.tex
#     -> Parsing input: introduction.tex
#     -> Parsing input: result2.tex
#     -> Parsing input: sections/algorithm-a.tex
# [2211.03023] Done. Elements: 1265, Refs: 32
#     -> Parsing input: background.tex
# [2211.03037] Done. Elements: 0, Refs: 0
#     -> Parsing input: 05-inference.tex[2211.03029] Done. Elements: 376, Refs: 0
#
# [2211.03002] Done. Elements: 612, Refs: 29
#     -> Parsing input: conclusion.tex
#     -> Parsing input: relatedwork.tex
#     -> Parsing input: sections/results-new.tex
#     -> Parsing input: design.tex
# [2211.03001] Done. Elements: 674, Refs: 43
# [2211.03032] Done. Elements: 593, Refs: 33
#     -> Parsing input: sections/relatedwork.tex
#     -> Parsing input: implementation.tex
#     -> Parsing input: sections/conclusion.tex
# [2211.03008] Done. Elements: 646, Refs: 0
# [2211.03021] Done. Elements: 443, Refs: 0
# [2211.03020] Done. Elements: 481, Refs: 28
#     -> Parsing input: 06-discussion.tex
#     -> Parsing input: sections/appendix.tex
#     -> Parsing input: evaluation.tex
# [2211.03035] Done. Elements: 375, Refs: 17
#     -> Parsing input: tables/conntime.tex
#     -> Parsing input: sections/abstract.tex
#     -> Parsing input: 07-conclusion.tex
#     -> Parsing input: tables/delay.tex
#     -> Parsing input: sections/intro.tex
#     -> Parsing input: lessons.tex
#     -> Parsing input: 08-appendix.tex
#     -> Parsing input: sections/related.tex
# [2211.03036] Done. Elements: 259, Refs: 28
#     -> Parsing input: Introduction.tex
# [2211.03047] Done. Elements: 0, Refs: 0
#     -> Parsing input: tables/mobileos.tex
# [2211.03038] Done. Elements: 211, Refs: 27
#     -> Parsing input: sections/dataset.tex
#     -> Parsing input: Method.tex
#     -> Parsing input: tables/remote.tex
#     -> Parsing input: conclusion.tex
#     -> Parsing input: sections/network.tex
#     -> Parsing input: appendix.tex
#     -> Parsing input: Exp.tex
#     -> Parsing input: sections/training.tex
# [2211.03040] Done. Elements: 177, Refs: 11
#     -> Parsing input: sections/experiments.tex
#     -> Parsing input: Conclusion.tex
# [2211.03056] Done. Elements: 0, Refs: 0
#     -> Parsing input: Appendix.tex    -> Parsing input: intro.tex
# [2211.03011] Done. Elements: 1036, Refs: 78
#
#     -> Parsing input: method.tex
#     -> Parsing input: sections/conclusion.tex
# [2211.03009] Done. Elements: 860, Refs: 119
# [2211.03015] Done. Elements: 562, Refs: 75
#     -> Parsing input: experiment.tex
#     -> Parsing input: conclusion.tex
#     -> Parsing input: sections/abstract.tex
# [2211.03039] Done. Elements: 343, Refs: 32    -> Parsing input: appendix.tex
#
# [2211.03045] Done. Elements: 714, Refs: 58
#     -> Parsing input: ./ifi_pages.tex
#     -> Parsing input: sections/intro.tex
#     -> Parsing input: sections/related.tex
# [2211.03060] Done. Elements: 0, Refs: 0
#     -> Parsing input: sections/dataset.tex
# [2211.03052] Done. Elements: 1176, Refs: 52
#     -> Parsing input: sections/network.tex[2211.03049] Done. Elements: 582, Refs: 0
#
#     -> Parsing input: math_commands.tex
#     -> Parsing input: sections/training.tex
# [2211.03041] Done. Elements: 342, Refs: 39
#     -> Parsing input: sections/experiments.tex
# [2211.03033] Done. Elements: 503, Refs: 50
# [2211.03058] Done. Elements: 482, Refs: 57
#     -> Parsing input: sections/conclusion.tex
# [2211.03059] Done. Elements: 2, Refs: 7
# [2211.03061] Done. Elements: 593, Refs: 27
# [2211.03050] Done. Elements: 782, Refs: 43
# [2211.03053] Done. Elements: 401, Refs: 17
# [2211.03017] Done. Elements: 482, Refs: 47
# [2211.03072] Done. Elements: 0, Refs: 0
#     -> Parsing input: constants.tex
# [2211.03062] Done. Elements: 609, Refs: 53
# [2211.03057] Done. Elements: 451, Refs: 15
# [2211.03055] Done. Elements: 489, Refs: 36
#     -> Parsing input: cvpr_header.tex[2211.03071] Done. Elements: 0, Refs: 0
#
#     -> Parsing input: macros.tex[2211.03063] Done. Elements: 792, Refs: 43
#
# [2211.03075] Done. Elements: 0, Refs: 0
#     -> Parsing input: tex/abstract.tex
#     -> Parsing input: sections/00_abstract.tex
#     -> Parsing input: tex/intro.tex
# [2211.03046] Done. Elements: 754, Refs: 51    -> Parsing input: sections/01_introduction.tex
#
# [2211.03068] Done. Elements: 577, Refs: 21
#     -> Parsing input: tex/related_works.tex
#     -> Parsing input: abbreviations.tex
#     -> Parsing input: sections/02_model_architecture.tex
#     -> Parsing input: tex/method.tex
#     -> Parsing input: sections/03_methods.tex
#     -> Parsing input: sections/04_results.tex
#     -> Parsing input: sections/05_discussion.tex
#     -> Parsing input: tex/experiments2.tex
# [2211.03073] Done. Elements: 180, Refs: 31
#     -> Parsing input: sections/06_conclusion.tex
# [2211.03048] Done. Elements: 723, Refs: 119
# [2211.03054] Done. Elements: 1440, Refs: 73
# [2211.03067] Done. Elements: 511, Refs: 8
#     -> Parsing input: sections/07_thanks.tex
#     -> Parsing input: tex/Tables/Architectures.tex
#     -> Parsing input: tex/Tables/position.tex
#     -> Parsing input: tex/Tables/movinet_clean.tex
# [2211.03081] Done. Elements: 0, Refs: 0
#     -> Parsing input: tex/Tables/FinalResults.tex
#     -> Parsing input: abbreviations.tex
#     -> Parsing input: tex/Tables/Device.tex
#     -> Parsing input: constants.tex    -> Parsing input: tex/conclusion.tex
#
# [2211.03080] Done. Elements: 0, Refs: 0
# [2211.03076] Done. Elements: 951, Refs: 0
#     -> Parsing input: cvpr_header.tex
#     -> Parsing input: macros.tex
#     -> Parsing input: sections/00_abstract.tex
#     -> Parsing input: sections/01_introduction.tex
# [2211.03078] Done. Elements: 229, Refs: 31
# [2211.03065] Done. Elements: 1027, Refs: 45
# [2211.03066] Done. Elements: 1204, Refs: 60
#     -> Parsing input: tex/abstract.tex
# [2211.03069] Done. Elements: 517, Refs: 17
#     -> Parsing input: sections/02_model_architecture.tex
# [2211.03087] Done. Elements: 0, Refs: 0
# [2211.03092] Done. Elements: 0, Refs: 0
#     -> Parsing input: tex/intro.tex
#     -> Parsing input: sections/03_methods.tex
#     -> Parsing input: tex/related_works.tex
#     -> Parsing input: tex/method.tex
# [2211.03031] Done. Elements: 1534, Refs: 54
#     -> Parsing input: sections/04_results.tex
#     -> Parsing input: sections/05_discussion.tex
# [2211.03091] Done. Elements: 0, Refs: 0
# [2211.03090] Done. Elements: 0, Refs: 0
#     -> Parsing input: tex/experiments.tex
#     -> Parsing input: sections/06_conclusion.tex
#     -> Parsing input: Sections/0-abs.tex[2211.03088] Done. Elements: 1, Refs: 59
#
#     -> Parsing input: sections/07_thanks.tex
#     -> Parsing input: tex/Tables/Architectures.tex
#     -> Parsing input: tex/Tables/position.tex
# [2211.03070] Done. Elements: 1, Refs: 0
#     -> Parsing input: Sections/1-intro.tex
# [2211.03084] Done. Elements: 505, Refs: 64
#     -> Parsing input: Sections/2-related.tex
# [2211.03064] Done. Elements: 932, Refs: 48
#     -> Parsing input: tex/Tables/movinet_clean.tex
#     -> Parsing input: Sections/3-method.tex
#     -> Parsing input: macro.tex
#     -> Parsing input: tex/Tables/FinalResults.tex
#     -> Parsing input: tex/Tables/delta.tex
#     -> Parsing input: abstract.tex
# [2211.03051] Done. Elements: 205, Refs: 18[2211.03074] Done. Elements: 1878, Refs: 0
#
# [2211.03096] Done. Elements: 0, Refs: 0
#     -> Parsing input: tex/Tables/Device.tex
#     -> Parsing input: introduction.tex
# [2211.03103] Done. Elements: 0, Refs: 0
#     -> Parsing input: Figs/overview.tex
#     -> Parsing input: tex/conclusion.tex
#     -> Parsing input: Figs/motivation_fig.tex
#     -> Parsing input: preliminaries.tex
#     -> Parsing input: Sections/4-setup.tex
# [2211.03085] Done. Elements: 1300, Refs: 0
#     -> Parsing input: half-greedy.tex
#     -> Parsing input: Sections/5-exp.tex
#     -> Parsing input: binary.tex
#     -> Parsing input: Tables/main_res.tex
# [2211.03108] Done. Elements: 0, Refs: 0
#     -> Parsing input: general.tex
#     -> Parsing input: Tables/ablation.tex
#     -> Parsing input: Figs/plots.tex
#
# [TIMEOUT] Paper 2211.03004 exceeded 30s.
# [2211.03004] Done. Elements: 437, Refs: 41
# [2211.03099] Done. Elements: 415, Refs: 0
#     -> Parsing input: lower-bound.tex
#     -> Parsing input: Tables/case_study.tex
#     -> Parsing input: Sections/6-concl.tex
#   [Cleanup] Removed partial folder for 2211.03004
#     -> Parsing input: appendix.tex
# [2211.03042] Done. Elements: 1, Refs: 53
#     -> Parsing input: Sections/7-app.tex
# [2211.03097] Done. Elements: 639, Refs: 0[2211.03098] Done. Elements: 291, Refs: 40
#     -> Parsing input: decl.tex
#
# [2211.03110] Done. Elements: 0, Refs: 0
#     -> Parsing input: definitions.tex
#     -> Parsing input: Tables/full_prompts.tex
# [2211.03101] Done. Elements: 576, Refs: 39
#     -> Parsing input: macro.tex
#     -> Parsing input: Tables/gen_hyperpara.tex
#     -> Parsing input: abstract.tex
# [2211.03093] Done. Elements: 1082, Refs: 46
# [2211.03104] Done. Elements: 1137, Refs: 0    -> Parsing input: introduction.tex
#     -> Parsing input: 0_abstract.tex
#
#     -> Parsing input: Tables/gpt3mix_prompt.tex
#     -> Parsing input: 1_intro.tex
#     -> Parsing input: Figs/visualize.tex
#     -> Parsing input: 2_related.tex
# [2211.03109] Done. Elements: 192, Refs: 17
#     -> Parsing input: preliminaries.tex
#     -> Parsing input: 3_method.tex
#     -> Parsing input: NeurIPS_2020_version/Section1_Introduction.tex
# [2211.03111] Done. Elements: 0, Refs: 0
#     -> Parsing input: NeurIPS_2020_version/Section2_ExistingWorks.tex
#     -> Parsing input: Sections/0-abs.tex
# [2211.03100] Done. Elements: 210, Refs: 17
# [2211.03095] Done. Elements: 847, Refs: 15    -> Parsing input: 4_exp.tex
#     -> Parsing input: half-greedy.tex
#
#     -> Parsing input: NeurIPS_2020_version/Section3_Architecture.tex
#     -> Parsing input: Sections/1-intro.tex
# [2211.03086] Done. Elements: 988, Refs: 73
#     -> Parsing input: Sections/2-related.tex
# [2211.03106] Done. Elements: 1, Refs: 18
#     -> Parsing input: NeurIPS_2020_version/Section3_Environment.tex
#     -> Parsing input: 5_con.tex
#     -> Parsing input: binary.tex
#     -> Parsing input: Sections/3-method.tex
#     -> Parsing input: NeurIPS_2020_version/Section4_Evaluation.tex
#     -> Parsing input: general.tex
# [2211.03120] Done. Elements: 0, Refs: 0
#     -> Parsing input: NeurIPS_2020_version/appendix.tex
#     -> Parsing input: Figs/overview.tex
#     -> Parsing input: lower-bound.tex
#     -> Parsing input: decl.tex
# [2211.03094] Done. Elements: 623, Refs: 81
#     -> Parsing input: Figs/motivation_fig.tex
#     -> Parsing input: conclusion.tex    -> Parsing input: definitions.tex
#
#     -> Parsing input: Sections/4-setup.tex
#     -> Parsing input: Tables/main_res.tex
#     -> Parsing input: 0_abstract.tex
# [2211.03121] Done. Elements: 0, Refs: 0
#     -> Parsing input: Sections/5-exp.tex
#     -> Parsing input: 1_intro.tex
# [2211.03123] Done. Elements: 0, Refs: 0
# [2211.03113] Done. Elements: 366, Refs: 72
# [2211.03082] Done. Elements: 1039, Refs: 39
# [2211.03043] Done. Elements: 5405, Refs: 2
# [2211.03126] Done. Elements: 0, Refs: 0
#     -> Parsing input: 2_related.tex
# [2211.03112] Done. Elements: 623, Refs: 0
#     -> Parsing input: Tables/ablation.tex
#     -> Parsing input: 3_method.tex
# [2211.03077] Done. Elements: 1128, Refs: 29
#     -> Parsing input: Figs/plots.tex
# [2211.03105] Done. Elements: 390, Refs: 60
#     -> Parsing input: Tables/gen_eval.tex
#     -> Parsing input: 4_exp.tex
# [2211.03107] Done. Elements: 762, Refs: 65
#     -> Parsing input: Tables/case_study.tex
#     -> Parsing input: 5_con.tex
# [2211.03122] Done. Elements: 257, Refs: 7
#     -> Parsing input: Figs/visualize.tex
# [2211.03118] Done. Elements: 615, Refs: 29
#     -> Parsing input: Sections/6-concl.tex
# [2211.03125] Done. Elements: 254, Refs: 17
# [2211.03119] Done. Elements: 777, Refs: 32
#     -> Parsing input: Sections/7-app.tex
# [2211.03133] Done. Elements: 0, Refs: 0
# [2211.03114] Done. Elements: 524, Refs: 32
# [2211.03089] Done. Elements: 328, Refs: 27
# [2211.03083] Done. Elements: 1574, Refs: 113
#     -> Parsing input: Tables/full_prompts.tex[2211.03138] Done. Elements: 0, Refs: 0
#
# [2211.03140] Done. Elements: 0, Refs: 0
# [2211.03102] Done. Elements: 1432, Refs: 62
#     -> Parsing input: Tables/gen_hyperpara.tex
#     -> Parsing input: Tables/gpt3mix_prompt.tex
#     -> Parsing input: Tables/app_case_study.tex
# [2211.03143] Done. Elements: 0, Refs: 0
# [2211.03142] Done. Elements: 70, Refs: 17
#     -> Parsing input: Tables/app_sst2_kshot.tex
# [2211.03129] Done. Elements: 1493, Refs: 27
#     -> Parsing input: preamble.tex[2211.03141] Done. Elements: 298, Refs: 29
#
#     -> Parsing input: text/abstract.tex
#     -> Parsing input: Sections/01-Introduction.tex
# [2211.03147] Done. Elements: 0, Refs: 0
#     -> Parsing input: text/introduction.tex
#     -> Parsing input: Sections/02-Background.tex
# [2211.03124] Done. Elements: 10, Refs: 0
#     -> Parsing input: Sections/03-threat_model.tex
# [2211.03131] Done. Elements: 1413, Refs: 28[2211.03136] Done. Elements: 433, Refs: 37
#
#     -> Parsing input: text/research_method.tex
#     -> Parsing input: Sections/06_case_study_speech_classification.tex
# [2211.03115] Done. Elements: 1296, Refs: 38    -> Parsing input: questionnaire_rq0.tex
#
# [2211.03044] Done. Elements: 964, Refs: 93
#     -> Parsing input: LaTeX/1_introduction.tex
#     -> Parsing input: Sections/08-Conclusions.tex
#     -> Parsing input: questionnaire_rq1.tex
# [2211.03127] Done. Elements: 278, Refs: 26
# [2211.03145] Done. Elements: 744, Refs: 19
#     -> Parsing input: LaTeX/2_related_works.tex
#     -> Parsing input: questionnaire_rq2.tex
#     -> Parsing input: questionnaire_rq3.tex
#     -> Parsing input: LaTeX/3_middleGAN.tex
# [2211.03152] Done. Elements: 279, Refs: 24
#     -> Parsing input: text/results.tex
# [2211.03151] Done. Elements: 362, Refs: 12
# [2211.03137] Done. Elements: 394, Refs: 19
#     -> Parsing input: preamble.tex
# [2211.03135] Done. Elements: 866, Refs: 42
#     -> Parsing input: LaTeX/4_evaluation.tex
#     -> Parsing input: macro_en.tex
# [2211.03134] Done. Elements: 1259, Refs: 39
#     -> Parsing input: Sections/01-Introduction.tex
# [2211.03153] Done. Elements: 6, Refs: 26
#     -> Parsing input: tables/codes_q1-3.tex
#     -> Parsing input: LaTeX/6_conclusion.tex
#     -> Parsing input: Sections/02-Background.tex
#     -> Parsing input: tables/codes_q2-1.tex
# [2211.03148] Done. Elements: 382, Refs: 34
#     -> Parsing input: Sections/03-threat_model.tex
# [2211.03157] Done. Elements: 0, Refs: 0
#     -> Parsing input: Sections/06-case_study_speech_classification.tex    -> Parsing input: tables/codes_q3-1.tex
#
# [2211.03144] Done. Elements: 429, Refs: 45
#     -> Parsing input: tables/codes_q3-2.tex
#     -> Parsing input: Sections/08-Conclusions.tex
# [2211.03159] Done. Elements: 181, Refs: 38
#     -> Parsing input: tables/codes_q3-3.tex
# [2211.03132] Done. Elements: 1058, Refs: 42
#     -> Parsing input: 1_0_introduction.tex
# [2211.03154] Done. Elements: 655, Refs: 174
#     -> Parsing input: 2_0_related_works.tex
#     -> Parsing input: tables/codes_q3-6.tex
#     -> Parsing input: preamble.tex
#     -> Parsing input: Sections/01-Introduction.tex
# [2211.03150] Done. Elements: 1278, Refs: 0
#     -> Parsing input: tables/codes_q3-7.tex
#     -> Parsing input: Sections/02-Background.tex
#     -> Parsing input: tables/codes_q3-8.tex
# [2211.03146] Done. Elements: 6, Refs: 0
#     -> Parsing input: 3_0_acoustics.tex
#     -> Parsing input: Sections/03-Threat-Model.tex
# [2211.03166] Done. Elements: 0, Refs: 0
#     -> Parsing input: tables/codes_q4-2.tex
# [2211.03164] Done. Elements: 0, Refs: 0
#     -> Parsing input: tables/codes_q4-4.tex
#     -> Parsing input: 4_0_PCR-W_system.tex
#     -> Parsing input: Sections/06-Case-study-speech-classification.tex
#     -> Parsing input: tables/codes_q4-5.tex
#     -> Parsing input: 5_0_evaluation.tex
#     -> Parsing input: 5_1_VAD.tex
#     -> Parsing input: tables/codes_q4-7.tex
#     -> Parsing input: general.tex
#     -> Parsing input: Sections/08-Conclusions.tex
# [2211.03162] Done. Elements: 646, Refs: 49
# [2211.03158] Done. Elements: 1201, Refs: 0    -> Parsing input: construction.tex
#     -> Parsing input: tables/codes_q4-9.tex
#     -> Parsing input: 5_2_SID.tex
#
#     -> Parsing input: 5_3_mood.tex
#     -> Parsing input: text/cross_analysis.tex
# [2211.03155] Done. Elements: 1338, Refs: 59
#     -> Parsing input: appendix.tex
#     -> Parsing input: 5_4_conflict.tex
# [2211.03117] Done. Elements: 464, Refs: 24
#     -> Parsing input: 5_5_acoustic_summary.tex
#     -> Parsing input: text/conclusions.tex
#     -> Parsing input: 6_0_adaptability.tex
#
# [TIMEOUT] Paper 2211.03013 exceeded 30s.
# [2211.03163] Done. Elements: 1, Refs: 699
#     -> Parsing input: 7_0_privacy.tex
# [2211.03156] Done. Elements: 1, Refs: 56
#   [Cleanup] Removed partial folder for 2211.03013
# [2211.03172] Done. Elements: 0, Refs: 0
# [2211.03170] Done. Elements: 534, Refs: 39
# [2211.03165] Done. Elements: 566, Refs: 0
#     -> Parsing input: 9_0_conclusion.tex
# [2211.03160] Done. Elements: 580, Refs: 50
# [2211.03161] Done. Elements: 1555, Refs: 19
# [2211.03180] Done. Elements: 0, Refs: 0
# [2211.03173] Done. Elements: 238, Refs: 17
# [2211.03179] Done. Elements: 171, Refs: 0
#     -> Parsing input: Sections/Introduction.tex
# [2211.03139] Done. Elements: 1016, Refs: 0[2211.03188] Done. Elements: 0, Refs: 0
#
#     -> Parsing input: Sections/Background.tex
#     -> Parsing input: Sections/Approach.tex
# [2211.03149] Done. Elements: 553, Refs: 43
# [2211.03116] Done. Elements: 865, Refs: 52    -> Parsing input: Sections/Experiments.tex
#
# [2211.03187] Done. Elements: 0, Refs: 0
#     -> Parsing input: Sections/Discussion.tex
#     -> Parsing input: Sections/Appendix.tex
# [2211.03189] Done. Elements: 0, Refs: 0
# [2211.03176] Done. Elements: 910, Refs: 85
# [2211.03190] Done. Elements: 179, Refs: 5
# [2211.03191] Done. Elements: 0, Refs: 0
# [2211.03178] Done. Elements: 841, Refs: 0
# [2211.03183] Done. Elements: 373, Refs: 28
# [2211.03177] Done. Elements: 467, Refs: 36
# [2211.03184] Done. Elements: 308, Refs: 23
# [2211.03181] Done. Elements: 994, Refs: 0
# [2211.03196] Done. Elements: 0, Refs: 0
# [2211.03182] Done. Elements: 1624, Refs: 10[2211.03174] Done. Elements: 427, Refs: 30
#
#     -> Parsing input: math_help.tex
#     -> Parsing input: docs/appendix.tex
#     -> Parsing input: tables/folktables_columns.tex
# [2211.03200] Done. Elements: 0, Refs: 0
# [2211.03171] Done. Elements: 371, Refs: 23
# [2211.03197] Done. Elements: 0, Refs: 0
# [2211.03169] Done. Elements: 1300, Refs: 46
# [2211.03202] Done. Elements: 0, Refs: 0
# [2211.03195] Done. Elements: 219, Refs: 36
# [2211.03207] Done. Elements: 0, Refs: 0
# [2211.03205] Done. Elements: 0, Refs: 0
#     -> Parsing input: math_help.tex
# [2211.03185] Done. Elements: 604, Refs: 18
#     -> Parsing input: math_help.tex
#     -> Parsing input: docs/appendix.tex
# [2211.03210] Done. Elements: 295, Refs: 2
#     -> Parsing input: tables/folktables_columns.tex
# [2211.03193] Done. Elements: 433, Refs: 32
# [2211.03175] Done. Elements: 1539, Refs: 71[2211.03198] Done. Elements: 289, Refs: 48
#
# [2211.03204] Done. Elements: 768, Refs: 68
# [2211.03215] Done. Elements: 215, Refs: 0
# [2211.03206] Done. Elements: 834, Refs: 38
#     -> Parsing input: 1_introduction.tex
#     -> Parsing input: intro.tex
# [2211.03128] Done. Elements: 862, Refs: 18
# [2211.03211] Done. Elements: 223, Refs: 15
#     -> Parsing input: 4_related_work.tex
# [2211.03186] Done. Elements: 206, Refs: 23
# [2211.03213] Done. Elements: 399, Refs: 39
# [2211.03201] Done. Elements: 1071, Refs: 74
#     -> Parsing input: 2_method.tex
#     -> Parsing input: related_work.tex
# [2211.03212] Done. Elements: 656, Refs: 14
# [2211.03130] Done. Elements: 1751, Refs: 12
#     -> Parsing input: 3_results.tex    -> Parsing input: matt-method.tex
# [2211.03208] Done. Elements: 710, Refs: 135
#
#     -> Parsing input: results.tex
# [2211.03223] Done. Elements: 0, Refs: 0
#     -> Parsing input: 5_conclusions.tex
#     -> Parsing input: main_timing_table.tex
#     -> Parsing input: 6_acknowledgements.tex
#     -> Parsing input: discussion.tex
# [2211.03227] Done. Elements: 0, Refs: 0
# [2211.03217] Done. Elements: 574, Refs: 28
#     -> Parsing input: math_commands.tex
# [2211.03218] Done. Elements: 670, Refs: 34
# [2211.03203] Done. Elements: 4, Refs: 0
# [2211.03230] Done. Elements: 0, Refs: 0
# [2211.03228] Done. Elements: 0, Refs: 0
# [2211.03219] Done. Elements: 736, Refs: 45
# [2211.03167] Done. Elements: 9, Refs: 38
# [2211.03209] Done. Elements: 419, Refs: 18
# [2211.03199] Done. Elements: 532, Refs: 35
# [2211.03220] Done. Elements: 6, Refs: 0
#     -> Parsing input: intro.tex
#     -> Parsing input: related_work.tex
#     -> Parsing input: matt-method.tex
# [2211.03239] Done. Elements: 0, Refs: 0
# [2211.03222] Done. Elements: 331, Refs: 41
#     -> Parsing input: results.tex
# [2211.03235] Done. Elements: 510, Refs: 0
# [2211.03244] Done. Elements: 0, Refs: 0
# [2211.03243] Done. Elements: 0, Refs: 0
#     -> Parsing input: main_timing_table.tex
# [2211.03234] Done. Elements: 913, Refs: 24
# [2211.03238] Done. Elements: 579, Refs: 31
#
# [TIMEOUT] Paper 2211.03079 exceeded 30s.
#     -> Parsing input: discussion.tex
# [2211.03216] Done. Elements: 1160, Refs: 61
#   [Cleanup] Removed partial folder for 2211.03079
#     -> Parsing input: commands.tex
# [2211.03214] Done. Elements: 967, Refs: 53
#     -> Parsing input: options.tex
# [2211.03240] Done. Elements: 535, Refs: 25
#     -> Parsing input: defs.tex
# [2211.03246] Done. Elements: 582, Refs: 51
#     -> Parsing input: intro.tex
#     -> Parsing input: math_commands.tex
# [2211.03192] Done. Elements: 792, Refs: 52
# [2211.03237] Done. Elements: 639, Refs: 35[2211.03245] Done. Elements: 1338, Refs: 0
#
#     -> Parsing input: packages.tex
#     -> Parsing input: Sections/Introduction.tex
#     -> Parsing input: commands.tex
# [2211.03249] Done. Elements: 0, Refs: 0
#     -> Parsing input: sections/0_abstract.tex
# [2211.03242] Done. Elements: 408, Refs: 26
#     -> Parsing input: model.tex
#     -> Parsing input: Sections/RelatedWork.tex
#     -> Parsing input: sections/1_introduction.tex
# [2211.03255] Done. Elements: 0, Refs: 0
#     -> Parsing input: Sections/Dataset.tex
#     -> Parsing input: sections/2_methods.tex    -> Parsing input: Sections/Methods.tex
#
# [2211.03241] Done. Elements: 1090, Refs: 0
#     -> Parsing input: Sections/Unsupervised_Generation.tex    -> Parsing input: symbolic.tex
#
# [2211.03248] Done. Elements: 684, Refs: 32
#     -> Parsing input: sections/results.tex
#     -> Parsing input: Sections/Conclusion.tex
#     -> Parsing input: contents/abstract.tex    -> Parsing input: macros.tex
#
#     -> Parsing input: Sections/appendix_example.tex
# [2211.03250] Done. Elements: 898, Refs: 31
#     -> Parsing input: commands.tex
#     -> Parsing input: tables/downstream_new.tex
#     -> Parsing input: contents/s1.tex
#     -> Parsing input: sections/4_discussion.tex
#     -> Parsing input: fig_bench.tex
#     -> Parsing input: Sections/Appendix_document_examples.tex
#     -> Parsing input: math_commands.tex    -> Parsing input: contents/s2.tex
#
# [2211.03232] Done. Elements: 2010, Refs: 40
#     -> Parsing input: ptree.tex    -> Parsing input: contents/s3.tex
#
#     -> Parsing input: sections/3_evaluation.tex
# [2211.03231] Done. Elements: 1031, Refs: 37
# [2211.03251] Done. Elements: 681, Refs: 39
#     -> Parsing input: header.tex
#     -> Parsing input: contents/s4.tex
#     -> Parsing input: tables/system.tex
# [2211.03229] Done. Elements: 508, Refs: 48
#     -> Parsing input: contents/s5.tex
#     -> Parsing input: tables/read_dataset.tex
# [2211.03236] Done. Elements: 1047, Refs: 50
# [2211.03247] Done. Elements: 514, Refs: 94
# [2211.03258] Done. Elements: 713, Refs: 0    -> Parsing input: sections/supp.tex
#
# [2211.03226] Done. Elements: 1788, Refs: 0
#     -> Parsing input: tables/model_compare.tex
# [2211.03254] Done. Elements: 819, Refs: 53
#     -> Parsing input: chapters/Introduction.tex
#     -> Parsing input: chapters/StaticModel.tex
# [2211.03224] Done. Elements: 3, Refs: 83
#     -> Parsing input: termination.tex
#     -> Parsing input: packages.tex
# [2211.03253] Done. Elements: 383, Refs: 23
#     -> Parsing input: chapters/DynamicFlows.tex
# [2211.03268] Done. Elements: 0, Refs: 0
#     -> Parsing input: commands.tex
#     -> Parsing input: math_commands.tex
#     -> Parsing input: chapters/CounterExample.tex
# [2211.03266] Done. Elements: 382, Refs: 32
#     -> Parsing input: sections/0_abstract.tex
#     -> Parsing input: sections/1_introduction.tex
# [2211.03260] Done. Elements: 3, Refs: 70
#     -> Parsing input: chapters/EquilibriumDefinition.tex
#     -> Parsing input: sections/2_methods.tex
# [2211.03261] Done. Elements: 398, Refs: 25    -> Parsing input: commands.tex
# [2211.03233] Done. Elements: 768, Refs: 57
#
# [2211.03259] Done. Elements: 434, Refs: 14
#     -> Parsing input: chapters/Characterization.tex
# [2211.03275] Done. Elements: 0, Refs: 0
#     -> Parsing input: sections/results.tex    -> Parsing input: conclusion.tex
#
# [2211.03256] Done. Elements: 489, Refs: 0
# [2211.03272] Done. Elements: 0, Refs: 0
#     -> Parsing input: chapters/SCviaNetworkLoading.tex
#     -> Parsing input: app_decision_ptree.tex
#     -> Parsing input: tables/downstream_new.tex
#     -> Parsing input: math_commands.tex
#     -> Parsing input: app_construct_ptree.tex
#     -> Parsing input: chapters/ExistenceResults.tex
#     -> Parsing input: sections/4_discussion.tex
#     -> Parsing input: sections/3_evaluation.tex
# [2211.03276] Done. Elements: 394, Refs: 5
# [2211.03221] Done. Elements: 1748, Refs: 10
# [2211.03263] Done. Elements: 543, Refs: 30
#     -> Parsing input: tables/system.tex
#     -> Parsing input: chapters/Conclusion.tex
#     -> Parsing input: tables/read_dataset.tex
#     -> Parsing input: chapters/ListOfSymbols.tex
# [2211.03267] Done. Elements: 745, Refs: 36
# [2211.03168] Done. Elements: 4482, Refs: 0
# [2211.03270] Done. Elements: 671, Refs: 43
#     -> Parsing input: sections/supp.tex
#     -> Parsing input: chapters/AdditionalExamples.tex
# [2211.03279] Done. Elements: 214, Refs: 20    -> Parsing input: chapters/VI-Solution-Existence.tex
#
# [2211.03278] Done. Elements: 375, Refs: 5
# [2211.03262] Done. Elements: 1245, Refs: 63
#     -> Parsing input: tables/model_compare.tex
# [2211.03287] Done. Elements: 0, Refs: 0
# [2211.03283] Done. Elements: 0, Refs: 0
#     -> Parsing input: app_termination.tex
#     -> Parsing input: app_complexity.tex
#     -> Parsing input: packages.tex
#     -> Parsing input: commands.tex
#     -> Parsing input: header.tex
#     -> Parsing input: sections/0_abstract.tex
#     -> Parsing input: sections/1_introduction.tex
# [2211.03280] Done. Elements: 726, Refs: 40
# [2211.03290] Done. Elements: 0, Refs: 0
#     -> Parsing input: sections/2_methods.tex
# [2211.03281] Done. Elements: 912, Refs: 0
# [2211.03289] Done. Elements: 0, Refs: 0
# [2211.03265] Done. Elements: 746, Refs: 0
#     -> Parsing input: sections/results.tex
# [2211.03284] Done. Elements: 254, Refs: 24
#     -> Parsing input: tables/downstream_new.tex
#     -> Parsing input: chapters/Introduction.tex
# [2211.03291] Done. Elements: 786, Refs: 0
#     -> Parsing input: sections/4_discussion.tex
# [2211.03264] Done. Elements: 1282, Refs: 80
# [2211.03271] Done. Elements: 519, Refs: 0
#     -> Parsing input: sections/3_evaluation.tex
#     -> Parsing input: Sections/01-intro.tex
#     -> Parsing input: chapters/StaticModel.tex
#     -> Parsing input: 1_introduction.tex
#     -> Parsing input: Sections/02-related.tex    -> Parsing input: tables/system.tex
#
#     -> Parsing input: tables/read_dataset.tex
# [2211.03299] Done. Elements: 0, Refs: 0
#     -> Parsing input: 2_background.tex
#     -> Parsing input: Sections/03-pilot.tex
#     -> Parsing input: chapters/DynamicFlows.tex
#     -> Parsing input: sections/supp.tex
#     -> Parsing input: Sections/04-study.tex
#     -> Parsing input: 3_relatedwork.tex
#     -> Parsing input: abstract.tex
#     -> Parsing input: tables/model_compare.tex
#     -> Parsing input: chapters/CounterExample.tex
# [2211.03282] Done. Elements: 305, Refs: 60
#     -> Parsing input: intro.tex
# [2211.03273] Done. Elements: 2093, Refs: 0
#     -> Parsing input: 4_overview.tex
#     -> Parsing input: 4-1_mutationscheme.tex
# [2211.03293] Done. Elements: 841, Refs: 0
#     -> Parsing input: preliminaries.tex    -> Parsing input: Sections/06-discussion.tex
#
#     -> Parsing input: preamble.tex
#     -> Parsing input: 4-2_newtarget2optimize.tex
#     -> Parsing input: chapters/EquilibriumDefinition.tex
# [2211.03297] Done. Elements: 317, Refs: 0
#     -> Parsing input: 4-3_banditcomparison.tex
# [2211.03303] Done. Elements: 0, Refs: 0
#     -> Parsing input: worst-case-small-rho.tex    -> Parsing input: paper-specific.tex
#     -> Parsing input: 5_evaluation.tex
#
#     -> Parsing input: packages.tex
#     -> Parsing input: introduction.tex
# [2211.03298] Done. Elements: 645, Refs: 0
#     -> Parsing input: Sections/07-conclusion.tex
# [2211.03307] Done. Elements: 0, Refs: 0
#     -> Parsing input: background.tex
#     -> Parsing input: commands.tex
#     -> Parsing input: chapters/Characterization.tex
# [2211.03257] Done. Elements: 3, Refs: 0
#     -> Parsing input: sections/0_abstract.tex    -> Parsing input: 6_discovery.tex
# [2211.03300] Done. Elements: 35, Refs: 65
#
#     -> Parsing input: worst-case-small-rho-upper-bound.tex
#     -> Parsing input: graph.tex
#     -> Parsing input: sections/1_introduction.tex
# [2211.03269] Done. Elements: 2044, Refs: 0
#     -> Parsing input: 7_discussion.tex    -> Parsing input: general-k-mixture2.tex
#
#     -> Parsing input: sections/2_methods.tex
# [2211.03296] Done. Elements: 430, Refs: 27
#     -> Parsing input: interpretation.tex
#     -> Parsing input: chapters/SCviaNetworkLoading.tex
#     -> Parsing input: 8_conclusion.tex
#     -> Parsing input: worst-case-small-delta3.tex
#     -> Parsing input: acknowledgement.tex
#     -> Parsing input: appendix.tex
#     -> Parsing input: average-case-small-rho.tex
#     -> Parsing input: sections/results.tex    -> Parsing input: chapters/ExistenceResults.tex
#
# [2211.03301] Done. Elements: 352, Refs: 40
#     -> Parsing input: discussion.tex
# [2211.03304] Done. Elements: 825, Refs: 40
# [2211.03305] Done. Elements: 392, Refs: 24
#     -> Parsing input: average-case-small-delta.tex
#     -> Parsing input: appendix.tex
#     -> Parsing input: tables/downstream_new.tex
#     -> Parsing input: theory-surface.tex
#     -> Parsing input: theory-syndromegraph.tex
#     -> Parsing input: src/intro.tex[2211.03285] Done. Elements: 601, Refs: 64
#
#     -> Parsing input: theory-perfectmatching.tex
#     -> Parsing input: sections/4_discussion.tex
#     -> Parsing input: chapters/Conclusion.tex
#     -> Parsing input: appendix.tex
#     -> Parsing input: src/related.tex
#     -> Parsing input: chapters/ListOfSymbols.tex
#     -> Parsing input: theory-uf-syndrome.tex
#     -> Parsing input: sections/3_evaluation.tex
#     -> Parsing input: appendix-fowlerdiagram.tex
#     -> Parsing input: style/definitions.tex
#     -> Parsing input: src/model.tex
#     -> Parsing input: section/title.tex
#     -> Parsing input: chapters/AdditionalExamples.tex
#     -> Parsing input: section/abstract.tex
#     -> Parsing input: chapters/VI-Solution-Existence.tex
#     -> Parsing input: tables/system.tex    -> Parsing input: src/algorithm.tex
#
#     -> Parsing input: section/introduction.tex
#     -> Parsing input: tables/read_dataset.tex
#     -> Parsing input: src/analysis.tex
#     -> Parsing input: sections/supp.tex
#     -> Parsing input: section/related_work.tex
#     -> Parsing input: src/preprocess.tex
#     -> Parsing input: tables/model_compare.tex
# [2211.03308] Done. Elements: 1055, Refs: 54
#     -> Parsing input: header.tex
#     -> Parsing input: src/experiments.tex
#     -> Parsing input: section/method_learn.tex
# [2211.03294] Done. Elements: 1153, Refs: 35
# [2211.03288] Done. Elements: 1047, Refs: 22
#     -> Parsing input: src/conclusion.tex
#     -> Parsing input: section/method_planning.tex
#     -> Parsing input: packages.tex
#     -> Parsing input: commands.tex
#     -> Parsing input: section/result_computation.tex    -> Parsing input: sections/0_abstract.tex
#
#     -> Parsing input: sections/1_introduction.tex
# [2211.03292] Done. Elements: 2858, Refs: 0    -> Parsing input: section/result_simulation.tex
#
#     -> Parsing input: chapters/Introduction.tex
#     -> Parsing input: sections/2_methods.tex
#     -> Parsing input: section/conclusion.tex
#     -> Parsing input: chapters/StaticModel.tex
# [2211.03306] Done. Elements: 847, Refs: 41
#     -> Parsing input: sections/results.tex
#     -> Parsing input: style/definitions.tex
#     -> Parsing input: section/title.tex
#     -> Parsing input: chapters/DynamicFlows.tex
#     -> Parsing input: section/abstract.tex
#     -> Parsing input: tables/downstream_new.tex    -> Parsing input: section/introduction.tex
#     -> Parsing input: chapters/CounterExample.tex
#
#     -> Parsing input: sections/4_discussion.tex
# [2211.03274] Done. Elements: 3056, Refs: 38
#     -> Parsing input: section/related_work.tex
# [2211.03310] Done. Elements: 1186, Refs: 51
#     -> Parsing input: chapters/EquilibriumDefinition.tex
#     -> Parsing input: section/method_learn.tex
#     -> Parsing input: sections/3_evaluation.tex
#     -> Parsing input: section/method_planning.tex
#     -> Parsing input: tables/system.tex
#     -> Parsing input: section/result_computation.tex    -> Parsing input: chapters/Characterization.tex
#
#     -> Parsing input: section/result_simulation.tex
#     -> Parsing input: tables/read_dataset.tex
# [2211.03302] Done. Elements: 4, Refs: 68
#     -> Parsing input: section/conclusion.tex
#     -> Parsing input: sections/supp.tex
#     -> Parsing input: chapters/SCviaNetworkLoading.tex
#     -> Parsing input: tables/model_compare.tex
#     -> Parsing input: chapters/ExistenceResults.tex
#
# [TIMEOUT] Paper 2211.03194 exceeded 30s.
#     -> Parsing input: packages.tex
#     -> Parsing input: commands.tex
# [2211.03286] Done. Elements: 524, Refs: 27
#     -> Parsing input: sections/0_abstract.tex
#   [Cleanup] Removed partial folder for 2211.03194
#     -> Parsing input: sections/1_introduction.tex
#     -> Parsing input: chapters/Conclusion.tex
#     -> Parsing input: chapters/ListOfSymbols.tex
#     -> Parsing input: sections/results.tex
#     -> Parsing input: chapters/AdditionalExamples.tex
#     -> Parsing input: chapters/VI-Solution-Existence.tex
#     -> Parsing input: tables/downstream_gb.tex
#     -> Parsing input: sections/4_discussion.tex
#     -> Parsing input: sections/conclusion.tex
#     -> Parsing input: sections/3_evaluation.tex
#     -> Parsing input: tables/system.tex
#     -> Parsing input: tables/read_dataset.tex
#     -> Parsing input: sections/supp.tex
#     -> Parsing input: sections/main_post.tex
#     -> Parsing input: intro.tex
#     -> Parsing input: tables/model_compare.tex
#     -> Parsing input: tables/read_mapping_compare.tex
#     -> Parsing input: motivation.tex
#     -> Parsing input: tables/kmer_compare.tex
#     -> Parsing input: figs/motivation.tex
#     -> Parsing input: overview.tex
#     -> Parsing input: figs/overview.tex
#     -> Parsing input: hardware.tex
#     -> Parsing input: packages.tex
#     -> Parsing input: commands.tex
#     -> Parsing input: 0_abstract.tex
#     -> Parsing input: figs/hardware-system-overview.tex
#     -> Parsing input: graph.tex
#     -> Parsing input: 1_introduction.tex
#     -> Parsing input: figs/transformation.tex
#     -> Parsing input: perf.tex
#     -> Parsing input: figs/validation.tex
#     -> Parsing input: 2_results.tex
#     -> Parsing input: search.tex
#     -> Parsing input: validation.tex
#     -> Parsing input: case.tex
#     -> Parsing input: table_downstream_gb.tex
# [2211.03225] Done. Elements: 6509, Refs: 59
#     -> Parsing input: related.tex
#     -> Parsing input: 3_discussion.tex    -> Parsing input: conc.tex
#
#     -> Parsing input: 4_conclusion.tex
#     -> Parsing input: 5_evaluation.tex
#     -> Parsing input: table_system.tex
#     -> Parsing input: table_read_dataset.tex
#     -> Parsing input: sections/supp.tex
#     -> Parsing input: sections/main_post.tex
#     -> Parsing input: intro.tex
#     -> Parsing input: tables/model_compare.tex
#     -> Parsing input: motivation.tex
#     -> Parsing input: tables/read_mapping_compare.tex
#     -> Parsing input: figs/motivation.tex
#     -> Parsing input: 0_abstract.tex
#     -> Parsing input: 1_introduction.tex
#     -> Parsing input: overview.tex
#     -> Parsing input: tables/kmer_compare.tex
#     -> Parsing input: figs/overview.tex
#     -> Parsing input: 3_method.tex
#     -> Parsing input: hardware.tex
#     -> Parsing input: Tabs/tab_attention.tex
#     -> Parsing input: figs/hardware-system-overview.tex
#     -> Parsing input: 4_experiments.tex
#     -> Parsing input: graph.tex
#     -> Parsing input: figs/transformation.tex    -> Parsing input: Tabs/tab_in1k_tiny.tex
#
#     -> Parsing input: Tabs/tab_in1k_small.tex
#     -> Parsing input: perf.tex
#     -> Parsing input: 2_related_works.tex
#     -> Parsing input: figs/validation.tex
#     -> Parsing input: 5_conclusion.tex
#     -> Parsing input: 6_appendix.tex
#     -> Parsing input: search.tex
#     -> Parsing input: validation.tex
#     -> Parsing input: case.tex
#     -> Parsing input: Tabs/tab_architecture.tex
#     -> Parsing input: Tabs/tab_train_conf.tex    -> Parsing input: related.tex
#
#     -> Parsing input: conc.tex
#     -> Parsing input: Tabs/tab_ablation_gate.tex
#     -> Parsing input: Tabs/tab_ablation_conv.tex
#     -> Parsing input: Tabs/tab_ablation_norm.tex
#     -> Parsing input: Tabs/tab_advanced_tiny.tex
#     -> Parsing input: Tabs/tab_in1k_app_rsb.tex
# [2211.03309] Done. Elements: 640, Refs: 16
#     -> Parsing input: math_commands.tex
#     -> Parsing input: 0_abstract.tex
#     -> Parsing input: 1_introduction.tex
#     -> Parsing input: 3_method.tex
#     -> Parsing input: 4_experiments.tex
#     -> Parsing input: Tabs/tab_3d_vp.tex
#     -> Parsing input: 2_related_works.tex
#     -> Parsing input: 5_conclusion.tex
#     -> Parsing input: 6_appendix.tex
#     -> Parsing input: Tabs/tab_architecture.tex
#     -> Parsing input: Tabs/tab_ablation_norm.tex
#     -> Parsing input: Tabs/tab_advanced_tiny.tex
#     -> Parsing input: Tabs/tab_coco_r_1x_app.tex
#     -> Parsing input: Tabs/tab_coco_m_1x_app.tex
#     -> Parsing input: Tabs/tab_coco_c_3x_app.tex
#     -> Parsing input: Tabs/tab_ade20k_uper_app.tex
#     -> Parsing input: Tabs/tab_3d_app.tex
#     -> Parsing input: Tabs/tab_coco_pose_app.tex
#     -> Parsing input: Tabs/tab_vp_app.tex
#     -> Parsing input: Tabs/tab_in1k_app_rsb.tex
#     -> Parsing input: math_commands.tex
#     -> Parsing input: 0_abstract.tex
#     -> Parsing input: 1_introduction.tex
#     -> Parsing input: 2_related_works.tex
#     -> Parsing input: 3_method.tex
#     -> Parsing input: 4_experiments.tex
#     -> Parsing input: Tabs/tab_3d_vp.tex
#     -> Parsing input: 5_conclusion.tex
#     -> Parsing input: 6_appendix.tex
#     -> Parsing input: Tabs/tab_architecture.tex
#     -> Parsing input: Tabs/tab_ablation_norm.tex
#     -> Parsing input: Tabs/tab_advanced_tiny.tex
#     -> Parsing input: Tabs/tab_coco_r_1x_app.tex
#     -> Parsing input: Tabs/tab_coco_m_1x_app.tex
#     -> Parsing input: Tabs/tab_coco_c_3x_app.tex
#     -> Parsing input: Tabs/tab_ade20k_uper_app.tex
#     -> Parsing input: Tabs/tab_3d_app.tex
#     -> Parsing input: Tabs/tab_coco_pose_app.tex
#     -> Parsing input: Tabs/tab_vp_app.tex
#     -> Parsing input: Tabs/tab_in1k_app_rsb.tex
# [2211.03295] Done. Elements: 2001, Refs: 158
#
# [TIMEOUT] Paper 2211.03252 exceeded 30s.
#   [Cleanup] Removed partial folder for 2211.03252
#     -> Parsing input: definition.tex
#     -> Parsing input: sec1-intro.tex
#     -> Parsing input: sec2-relat.tex
#     -> Parsing input: sec3-model.tex
#     -> Parsing input: sec4-exper.tex
#     -> Parsing input: sec5-concl.tex
# [2211.03277] Done. Elements: 421, Refs: 22
#     -> Parsing input: EACL_body/0_abstract.tex
#     -> Parsing input: EACL_body/1_introduction.tex
#     -> Parsing input: figures/teaser.tex
#     -> Parsing input: figures/approach.tex
#     -> Parsing input: EACL_body/2_related.tex
#     -> Parsing input: tables/interpretability.tex
#     -> Parsing input: EACL_body/3_approach.tex
#     -> Parsing input: tables/clues_main_results.tex
#     -> Parsing input: EACL_body/4_0.tex
#     -> Parsing input: figures/effect_of_complexity.tex
#     -> Parsing input: EACL_body/4_1_CLUES.tex
#     -> Parsing input: figures/argument_position.tex
#     -> Parsing input: EACL_body/4_2_results.tex
#     -> Parsing input: figures/robustness.tex
#     -> Parsing input: EACL_body/4_3_interpretability.tex
#     -> Parsing input: EACL_body/4_5_robustness.tex
#     -> Parsing input: tables/cub_main_results.tex
#     -> Parsing input: tables/ecthr_main_results.tex
#     -> Parsing input: EACL_body/5_0.tex
#     -> Parsing input: EACL_body/5_1_datasets.tex
#     -> Parsing input: EACL_body/5_2_setting.tex
#     -> Parsing input: EACL_body/5_3_results.tex
#     -> Parsing input: EACL_body/6_conclusion.tex
#     -> Parsing input: EACL_body/A_Appendix.tex
#     -> Parsing input: tables/all_program_templates.tex
#     -> Parsing input: figures/program_length.tex
#     -> Parsing input: tables/program_examples.tex
#     -> Parsing input: tables/execution_evidence.tex
#     -> Parsing input: figures/quantifiers.tex
#     -> Parsing input: EACL_body/4_4_quantifier_learning.tex
#     -> Parsing input: ACL_body/0_abstract.tex
#     -> Parsing input: ACL_body/1_introduction.tex
#     -> Parsing input: figures/teaser.tex
#     -> Parsing input: figures/approach.tex
#     -> Parsing input: ACL_body/2_related.tex
#     -> Parsing input: figures/parsing.tex
#     -> Parsing input: ACL_body/3_approach.tex
#     -> Parsing input: tables/clues_main_results.tex
#     -> Parsing input: ACL_body/4_0.tex
#     -> Parsing input: tables/program_examples.tex
#     -> Parsing input: figures/execution_evidence.tex
#     -> Parsing input: ACL_body/4_1_CLUES.tex
#     -> Parsing input: ACL_body/4_2_results.tex
#     -> Parsing input: ACL_body/4_3_effect_of_compositionality.tex
#     -> Parsing input: figures/program_length.tex
#     -> Parsing input: tables/compositional_example.tex
#     -> Parsing input: ACL_body/4_4_interpretability.tex
#     -> Parsing input: figures/argument_position.tex
#     -> Parsing input: figures/effect_of_complexity.tex
#     -> Parsing input: figures/robustness.tex
#     -> Parsing input: ACL_body/4_6_robustness.tex
#     -> Parsing input: figures/quantifiers.tex
#     -> Parsing input: ACL_body/4_5_quantifier_learning.tex
#     -> Parsing input: tables/cub_main_results.tex
#     -> Parsing input: ACL_body/5_0.tex
#     -> Parsing input: ACL_body/5_1_datasets.tex
#     -> Parsing input: ACL_body/5_2_setting.tex
#     -> Parsing input: ACL_body/5_3_results.tex
#     -> Parsing input: ACL_body/6_conclusion.tex
#     -> Parsing input: ACL_body/7_limitations.tex
#     -> Parsing input: ACL_body/8_broader_impact.tex
#     -> Parsing input: ACL_body/9_acknowledgement.tex
#     -> Parsing input: ACL_body/A_Appendix.tex
#     -> Parsing input: tables/all_program_templates.tex
# --------------------------------------------------
# Processing Complete.
# Total Failed/Timed-out: 5
# List of failed IDs saved to failed_ids.txt
